# %%
import pandas as pd

df=pd.read_csv('Olympic_Athlete_Event_Results.csv',encoding='ISO-8859-1',on_bad_lines='skip')

print("First few rows of the dataset:")
display(df.head())

print("Dataset Information:")
df.info()

print("Missing Values Count:")
missing_values = df.isnull().sum()
display(missing_values[missing_values > 0])

print("Statistical Summary for Numerical Colums:")
display(df.describe())

# Displaying basic statistical summary for categorical columns (like 'Event', 'Medal', etc.)
print("\nUnique Values in Each Column:")
for column in df.select_dtypes(include='object').columns:
    print(f"{column}: {df[column].nunique()} unique values")

# Check for unique categories in key columns (like 'Medal', 'Sport', etc.)
print("\nUnique Categories in Key Columns:")
print("Medal:", df['Medal'].unique())
print("Sport:", df['Sport'].unique())
print("Country:", df['Country'].unique())
# Out:
# <ipython-input-1-1fd6fac70555>:3: DtypeWarning: Columns (16,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Olympic_Athlete_Event_Results.csv',encoding='ISO-8859-1',on_bad_lines='skip')
# First few rows of the dataset:
#                   Games edition_id  NOC      Sport  \
# 0  1972 Summer Olympics         18  BEN  Athletics
# 1  1972 Summer Olympics         18  BEN  Athletics
# 2  1972 Summer Olympics         18  BEN     Boxing
# 3  1972 Summer Olympics         18  BEN     Boxing
# 4  1972 Summer Olympics         18  BIZ   Shooting
#
#                           Event  result_id                 Name athlete_id  \
# 0               400 metres, Men    61050.0    Ibrahima Idrissou      65351
# 1              Triple Jump, Men    61226.0   Christoph Chodaton     923484
# 2          Light-Flyweight, Men    24001.0  Meriga Salou Seriki       1692
# 3             Bantamweight, Men    24081.0       Leopold Agbazo       1691
# 4  Free Pistol, 50 metres, Open    51723.0        Owen Phillips      41408
#
#          pos Medal isTeamSport Height Weight        Born Country Unnamed: 15  \
# 0  6 h7 r1/4   NaN       FALSE    NaN    NaN  01-01-1940   Benin         NaN
# 1        DNS   NaN       FALSE    NaN    NaN         NaN   Benin         NaN
# 2         17   NaN       FALSE    157     48  08-04-1953   Benin         NaN
# 3         33   NaN       FALSE    159     54  25-01-1945   Benin         NaN
# 4         59   NaN       FALSE    175     76  09-07-2006  Belize         NaN
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213231 entries, 0 to 213230
# Data columns (total 19 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Games        212845 non-null  object
#  1   edition_id   213143 non-null  object
#  2   NOC          212794 non-null  object
#  3   Sport        211824 non-null  object
#  4   Event        213120 non-null  object
#  5   result_id    212952 non-null  float64
#  6   Name         212971 non-null  object
#  7   athlete_id   211298 non-null  object
#  8   pos          204267 non-null  object
#  9   Medal        35908 non-null   object
#  10  isTeamSport  208593 non-null  object
#  11  Height       186134 non-null  object
#  12  Weight       186809 non-null  object
#  13  Born         208916 non-null  object
#  14  Country      200180 non-null  object
#  15  Unnamed: 15  230 non-null     object
#  16  Unnamed: 16  5 non-null       object
#  17  Unnamed: 17  3 non-null       object
#  18  Unnamed: 18  1 non-null       object
# dtypes: float64(1), object(18)
# memory usage: 30.9+ MB
# Missing Values Count:
# Games             386
# edition_id         88
# NOC               437
# Sport            1407
# Event             111
# result_id         279
# Name              260
# athlete_id       1933
# pos              8964
# Medal          177323
# isTeamSport      4638
# Height          27097
# Weight          26422
# Born             4315
# Country         13051
# Unnamed: 15    213001
# Unnamed: 16    213226
# Unnamed: 17    213228
# Unnamed: 18    213230
# dtype: int64
# Statistical Summary for Numerical Colums:
#           result_id
# count  2.129520e+05
# mean   2.153281e+06
# std    5.697547e+06
# min    4.000000e+01
# 25%    2.969300e+04
# 50%    7.060500e+04
# 75%    3.223090e+05
# max    9.001677e+07
# Unique Values in Each Column:
# Games: 413 unique values
# edition_id: 798 unique values
# NOC: 424 unique values
# Sport: 75 unique values
# Event: 532 unique values
# Name: 103903 unique values
# athlete_id: 101091 unique values
# pos: 1537 unique values
# Medal: 77 unique values
# isTeamSport: 80 unique values
# Height: 218 unique values
# Weight: 3722 unique values
# Born: 22899 unique values
# Country: 306 unique values
# Unnamed: 15: 28 unique values
# Unnamed: 16: 4 unique values
# Unnamed: 17: 2 unique values
# Unnamed: 18: 1 unique values
#
# Unique Categories in Key Columns:
# Medal: [nan 'FALSE' 'TRUE' 'Silver' 'Bronze' 'Gold' '19' '47' '7' '2' '1' '4'
#  '51722' '5' '32' '=66 r1/1' '=51 r1/1' '53 r1/1' '17' '16' '12' '6' '3'
#  'DNF' '10' '8' '20' '11' 'AC' '29' '14' 'DQ' '7 h11 r1/4' '8 h8 r1/4'
#  'Francisco Garcl62088' '25' '26' '23' '36' '22' '3 h2 r2/4' '58 r1/2' '9'
#  'Fernando Lez62756' '13' '44' '35' '27' '50' '28' '34' '56' '7 h3 r1/4'
#  '15 h2 r1/2' '38' '18' '7 h2 r1/4' 'DNS' '8 h4 r1/3' '33'
#  'Armands B\x13rziFa' '24' '47 r1/2' '53 r1/2' '30 r1/2' '22 r1/2'
#  'Gints Meija' '31 r1/2' '51 r1/2' '=45 r1/2' '21' '36 r1/2' '12 r1/2'
#  '37 r1/2' '33 r1/2' '14 r1/2' '51' '49']
# Sport: ['Athletics' 'Boxing' 'Shooting' 'Weightlifting' 'Cycling Road'
#  'Cycling Track' 'Wrestling' 'Swimming' 'Equestrian Jumping' 'Rowing'
#  'Sailing' 'Canoe Sprint' 'Judo' 'Archery' 'Artistic Gymnastics'
#  'Volleyball' nan 'Diving' 'Football' 'Waterskiing' 'Canoe Slalom'
#  'Equestrian Dressage' 'Equestrian Eventing' 'Fencing' 'Handball'
#  'Basketball' 'Bronze' 'Water Polo' 'Hockey' 'Modern Pentathlon' 'FALSE'
#  'TRUE' 'Badminton' 'Speed Skating' 'Alpine Skiing' 'Cross Country Skiing'
#  'Biathlon' 'Figure Skating' 'Luge' 'Nordic Combined' 'Ski Jumping'
#  'Ice Hockey' 'Bobsleigh' 'Gold' 'Silver' 'Artistic Swimming' 'Baseball'
#  'Tennis' 'Rhythmic Gymnastics' 'Taekwondo' 'Table Tennis' 'Bowling'
#  'Freestyle Skiing' 'Short Track Speed Skating' 'Curling' 'Roller Hockey'
#  'Basque pelota' 'Speed Skiing' 'Cycling Mountain Bike' 'Softball'
#  'Beach Volleyball' 'Snowboarding' 'Trampolining' 'Triathlon' 'Wushu'
#  'Cycling BMX Racing' 'Marathon Swimming' 'Skeleton' 'Golf' 'Rugby Sevens'
#  'Karate' 'Cycling BMX Freestyle' 'Surfing' 'Skateboarding'
#  'Sport Climbing' '3x3 Basketball']
# Country: ['Benin' 'Belize' 'Albania' 'Barbados' 'Afghanistan' 'Burkina Faso'
#  'Cambodia' 'Algeria' 'Boliva' nan 'Bermuda' 'Chad' 'Cameroon'
#  'Republic of Congo' 'Ivory Coast' 'Costa Rica' 'Dominican Republic'
#  'North Korea' 'El Salvador' 'Ecuador' 'Colombia' 'Swaziland' 'Taiwan'
#  'Chile' 'Gabon' 'Ethiopia' 'Germany' 'Fiji' 'Cuba' 'Ghana' 'Egypt'
#  'Argentina' 'Bulgaria' 'Belgium' 'Guyana' 'Guatemala' 'Brazil' 'Haiti'
#  'Czech Republic' 'Indonesia' 'Austria' 'China' 'Denmark' 'Saudi Arabia'
#  'Kuwait' 'Israel' 'Iran' 'Iceland' 'Jamaica' 'Lesotho' 'Kenya' 'Liberia'
#  'Ireland' 'Australia' 'Malawi' 'India' 'Madagascar' 'Greece' 'Mali'
#  'Malta' 'Malaysia' 'Liechtenstein' '30-10-1945' 'Myanmar' 'Finland'
#  'Curacao' 'Luxembourg' 'Niger' 'Nicaragua' 'Nepal' 'Monaco' 'Morocco'
#  'Canada' 'Mongolia' 'Paraguay' 'Panama' 'Nigeria' 'Pakistan' 'Hungary'
#  '03-02-1945' 'Peru' 'Philippines' 'Mexico' '14-01-1952' 'Puerto Rico'
#  'Somalia' 'San Marino' 'Senegal' 'Vietnam' 'Portugal' 'New Zealand'
#  'Suriname' 'Sudan' 'Japan' 'Sri Lanka' 'Syria' 'Togo' 'Bahamas' 'France'
#  'Thailand' 'Trinidad' 'UK' 'Uganda' 'Tunisia' 'Tanzania' 'Netherlands'
#  '16-06-1954' 'Norway' 'South Korea' 'Romania' 'Virgin Islands, US'
#  'Italy' 'Zambia' 'Poland' 'Uruguay' 'Russia' 'Turkey' 'Venezuela' 'Spain'
#  'FALSE' 'Serbia' 'Switzerland' 'Sweden' '13-05-1941' 'USA' 'Antigua'
#  'Andorra' 'Cayman Islands' '07-06-1959' '27-09-1959' 'Honduras'
#  '21-09-1952' 'Papua New Guinea' '08-06-1950' '12-02-1957' '02-02-1955'
#  '16-03-1956' '04-11-1948' '08-07-1958' '23-03-1952' '01-09-1953' 'Angola'
#  'Botswana' 'Cyprus' 'Guinea' 'Iraq' 'Jordan' 'Laos' 'Libya' 'Mozambique'
#  'Seychelles' 'Sierra Leone' '20-01-1953' 'Zimbabwe' '15-08-1960'
#  '17-02-1946' 'Bangladesh' 'Bhutan' 'Bahrain' 'Virgin Islands, British'
#  'Central African Republic' 'Djibouti' 'Democratic Republic of the Congo'
#  'Equatorial Guinea' 'Grenada' 'Mauritania' 'Mauritius' 'Yemen' 'Oman'
#  'Qatar' 'Rwanda' 'Samoa' 'Solomon Islands' 'Gambia' 'Tonga' '11-10-1957'
#  'United Arab Emirates' '21-04-1954' '15-09-1961' 'Aruba' 'American Samoa'
#  'Cook Islands' '14-02-1965' 'Guam' '01-05-1960' 'Maldives' '15-06-1968'
#  'Saint Vincent' 'Vanuatu' '31-03-1966' '75' '20-02-1960' '18-01-1969'
#  '02-06-1973' '24-01-1961' '17-04-1970' '14-06-1967'
#  'Bosnia and Herzegovina' 'Croatia' '22-01-1972' 'Estonia'
#  'Individual Olympic Athletes' '30-01-1968' 'Latvia' 'Lithuania' 'Namibia'
#  '13-01-1969' '22-12-1951' '14-08-1970' 'Slovenia' 'South Africa' '72'
#  '17-08-1963' '19-06-1967' '26-03-1966' '15-12-1963' 'Armenia' 'Belarus'
#  'Georgia' 'Kyrgyzstan' 'Kazakhstan' 'Moldova' 'Slovakia' 'Uzbekistan'
#  'Ukraine' '25-07-1967' 'Brunei' 'Azerbaijan' 'Burundi' 'Cape Verde'
#  'Comoros' 'Dominica' 'Guinea-Bissau' 'Nauru' 'Macedonia' 'Palestine'
#  'Saint Kitts' 'Saint Lucia' 'Sao Tome and Principe' '18-03-1972'
#  'Tajikistan' 'Turkmenistan' '24-12-1962' '23-04-1977' '02-12-1978'
#  '10-12-1980' '26-03-1975' '05-06-1973' '14-07-1975' 'Eritrea'
#  'Micronesia' 'Palau' '05-11-1975' '25-04-1976' '21-04-1976' '21-01-1978'
#  '25-03-1977' '13-02-1978' '14-10-1974' '30-06-1972' '12-09-1983'
#  'Kiribati' '29-03-1974' 'Timor-Leste' '10-08-1979' '192' '28-08-1981'
#  '17-12-1977' '16-11-1991' 'Marshall Islands' 'Montenegro' '17-12-1983'
#  '183' '13-06-1985' '09-06-1992' '20-02-1986' '20-11-1987' '25-07-1989'
#  '27-08-1984' '30-09-1986' '17-07-1981' '25-05-1986' '06-04-1996'
#  '27-09-1993' 'Kosovo' '21-10-1983' 'South Sudan' '24-01-1983'
#  '20-04-1988' '13-12-1992' '12-05-1989' '28-01-1991' '13-12-1988'
#  '27-08-1992' '26-01-1985' '26-11-1997' '21-06-1990' '27-04-1987'
#  '15-07-1997' '20-04-2002' '07-01-2000' '07-05-1987' '17-08-1997'
#  '01-04-2000' '20-01-1995' '21-01-1998' '23-01-1992']

# %%
print(df.shape)
# Out:
# (213231, 19)

# %%
## As we can see that there are some misalignment in dataset
## the first task is to solve the misalignment problem by deleting those rows

## step 1: Drop rows where in column isTeamsport contain value other than true or false
# Drop rows where 'isTeamSport' is not exactly True or False
df_cleaned = df[df['isTeamSport'].isin(['TRUE','FALSE'])]
print(df_cleaned.shape)

print("Droping Unamed Columns .")
df_cleaned = df_cleaned.drop(columns=[col for col in df.columns if 'Unnamed' in col])

print(df_cleaned.shape)

## Droping rows with missing value of pos and country
df_cleaned = df_cleaned.dropna(subset=['pos', 'Country','Born'])

## Checking the missing values
print("Missing Values Count:")
missing_values = df_cleaned.isnull().sum()
print(missing_values)

# Displaying basic statistical summary for categorical columns (like 'Event', 'Medal', etc.)
print("\nUnique Values in Each Column:")
for column in df_cleaned.select_dtypes(include='object').columns:
    print(f"{column}: {df_cleaned[column].nunique()} unique values")
print(df_cleaned.shape)
# Check for unique categories in key columns (like 'Medal', 'Sport', etc.)
print("\nUnique Categories in Key Columns:")
print("Medal:", df_cleaned['Medal'].unique())
print("Sport:", df_cleaned['Sport'].unique())
print("Country:", df_cleaned['Country'].unique())
print("Edition ID:", df_cleaned['edition_id'].unique())
print("Athlete ID:", df_cleaned['athlete_id'].unique())
print("Height:", df_cleaned['Height'].unique())
print("Weight:", df_cleaned['Weight'].unique())
# Out:
# (201809, 19)
# Droping Unamed Columns .
# (201809, 15)
# Missing Values Count:
# Games               0
# edition_id          0
# NOC                 0
# Sport               0
# Event               0
# result_id           0
# Name                0
# athlete_id          0
# pos                 0
# Medal          171518
# isTeamSport         0
# Height          21504
# Weight          21504
# Born                0
# Country             0
# dtype: int64
#
# Unique Values in Each Column:
# Games: 27 unique values
# edition_id: 27 unique values
# NOC: 216 unique values
# Sport: 70 unique values
# Event: 490 unique values
# Name: 98206 unique values
# athlete_id: 98597 unique values
# pos: 1374 unique values
# Medal: 3 unique values
# isTeamSport: 2 unique values
# Height: 94 unique values
# Weight: 505 unique values
# Born: 22703 unique values
# Country: 204 unique values
# (199419, 15)
#
# Unique Categories in Key Columns:
# Medal: [nan 'Silver' 'Bronze' 'Gold']
# Sport: ['Athletics' 'Boxing' 'Shooting' 'Weightlifting' 'Cycling Road'
#  'Cycling Track' 'Wrestling' 'Swimming' 'Equestrian Jumping' 'Rowing'
#  'Sailing' 'Canoe Sprint' 'Judo' 'Archery' 'Artistic Gymnastics'
#  'Volleyball' 'Diving' 'Football' 'Waterskiing' 'Canoe Slalom'
#  'Equestrian Dressage' 'Equestrian Eventing' 'Fencing' 'Handball'
#  'Basketball' 'Water Polo' 'Hockey' 'Modern Pentathlon' 'Badminton'
#  'Speed Skating' 'Alpine Skiing' 'Cross Country Skiing' 'Biathlon'
#  'Figure Skating' 'Luge' 'Nordic Combined' 'Ski Jumping' 'Ice Hockey'
#  'Bobsleigh' 'Baseball' 'Tennis' 'Artistic Swimming' 'Rhythmic Gymnastics'
#  'Taekwondo' 'Table Tennis' 'Bowling' 'Freestyle Skiing'
#  'Short Track Speed Skating' 'Curling' 'Roller Hockey' 'Basque pelota'
#  'Speed Skiing' 'Cycling Mountain Bike' 'Softball' 'Beach Volleyball'
#  'Snowboarding' 'Trampolining' 'Triathlon' 'Cycling BMX Racing' 'Wushu'
#  'Marathon Swimming' 'Skeleton' 'Golf' 'Rugby Sevens' 'Karate'
#  'Cycling BMX Freestyle' 'Surfing' 'Skateboarding' 'Sport Climbing'
#  '3x3 Basketball']
# Country: ['Benin' 'Belize' 'Albania' 'Barbados' 'Afghanistan' 'Burkina Faso'
#  'Cambodia' 'Algeria' 'Boliva' 'Bermuda' 'Chad' 'Cameroon'
#  'Republic of Congo' 'Ivory Coast' 'Costa Rica' 'Dominican Republic'
#  'North Korea' 'El Salvador' 'Ecuador' 'Colombia' 'Swaziland' 'Taiwan'
#  'Chile' 'Gabon' 'Ethiopia' 'Germany' 'Fiji' 'Cuba' 'Ghana' 'Egypt'
#  'Argentina' 'Bulgaria' 'Belgium' 'Guyana' 'Guatemala' 'Brazil' 'Haiti'
#  'Czech Republic' 'Indonesia' 'Austria' 'China' 'Denmark' 'Saudi Arabia'
#  'Kuwait' 'Israel' 'Iran' 'Iceland' 'Jamaica' 'Lesotho' 'Kenya' 'Liberia'
#  'Ireland' 'Australia' 'Malawi' 'India' 'Madagascar' 'Greece' 'Mali'
#  'Malta' 'Malaysia' 'Liechtenstein' 'Myanmar' 'Finland' 'Curacao'
#  'Luxembourg' 'Niger' 'Nicaragua' 'Nepal' 'Monaco' 'Morocco' 'Canada'
#  'Mongolia' 'Paraguay' 'Panama' 'Nigeria' 'Pakistan' 'Hungary' 'Peru'
#  'Philippines' 'Mexico' 'Puerto Rico' 'Somalia' 'San Marino' 'Senegal'
#  'Vietnam' 'Portugal' 'New Zealand' 'Suriname' 'Sudan' 'Japan' 'Sri Lanka'
#  'Syria' 'Togo' 'Bahamas' 'France' 'Thailand' 'Trinidad' 'UK' 'Uganda'
#  'Tunisia' 'Tanzania' 'Netherlands' 'Norway' 'South Korea' 'Romania'
#  'Virgin Islands, US' 'Italy' 'Zambia' 'Poland' 'Uruguay' 'Russia'
#  'Turkey' 'Venezuela' 'Spain' 'Serbia' 'Switzerland' 'Sweden' 'USA'
#  'Antigua' 'Andorra' 'Cayman Islands' 'Honduras' 'Papua New Guinea'
#  'Angola' 'Botswana' 'Cyprus' 'Guinea' 'Iraq' 'Jordan' 'Laos' 'Libya'
#  'Mozambique' 'Seychelles' 'Sierra Leone' 'Zimbabwe' 'Bangladesh' 'Bhutan'
#  'Bahrain' 'Virgin Islands, British' 'Central African Republic' 'Djibouti'
#  'Democratic Republic of the Congo' 'Equatorial Guinea' 'Grenada'
#  'Mauritania' 'Mauritius' 'Yemen' 'Oman' 'Qatar' 'Rwanda' 'Samoa'
#  'Solomon Islands' 'Gambia' 'Tonga' 'United Arab Emirates' 'Aruba'
#  'American Samoa' 'Cook Islands' 'Guam' 'Maldives' 'Saint Vincent'
#  'Vanuatu' 'Bosnia and Herzegovina' 'Croatia' 'Estonia'
#  'Individual Olympic Athletes' 'Latvia' 'Lithuania' 'Namibia' 'Slovenia'
#  'South Africa' 'Armenia' 'Belarus' 'Georgia' 'Kyrgyzstan' 'Kazakhstan'
#  'Moldova' 'Slovakia' 'Uzbekistan' 'Ukraine' 'Brunei' 'Azerbaijan'
#  'Burundi' 'Cape Verde' 'Comoros' 'Dominica' 'Guinea-Bissau' 'Nauru'
#  'Macedonia' 'Palestine' 'Saint Kitts' 'Saint Lucia'
#  'Sao Tome and Principe' 'Tajikistan' 'Turkmenistan' 'Eritrea'
#  'Micronesia' 'Palau' 'Kiribati' 'Timor-Leste' 'Marshall Islands'
#  'Montenegro' 'Kosovo' 'South Sudan']
# Edition ID: ['18' '39' '19' '40' '20' '41' '21' '42' '22' '43' '23' '44' '45' '24'
#  '46' '25' '47' '26' '49' '53' '57' '54' '58' '59' '60' '61' '62']
# Athlete ID: ['65351' '1692' '1691' ... '148470' '148662' '149047']
# Height: [nan '157' '159' '175' '181' '167' '155' '168' '185' '170' '173' '166'
#  '147' '160' '165' '180' '171' '153' '183' '172' '163' '176' '184' '169'
#  '177' '178' '182' '162' '174' '158' '156' '195' '164' '150' '152' '139'
#  '186' '161' '154' '179' '189' '187' '191' '194' '190' '192' '193' '151'
#  '188' '197' '196' '198' '204' '200' '201' '206' '212' '213' '148' '130'
#  '199' '132' '202' '145' '208' '203' '210' '216' '207' '205' '209' '149'
#  '223' '143' '136' '146' '218' '137' '142' '220' '140' '144' '141' '135'
#  '214' '138' '211' '217' '127' '128' '221' '215' '226' '219' '133']
# Weight: [nan '48' '54' '76' '80' '61' '55' '68' '73' '75' '85' '84' '56' '63' '52'
#  '87' '67' '57' '65' '74' '70' '64' '58' '71' '59' '60' '77' '95' '62'
#  '86' '78' '81' '69' '72' '90' '88' '53' '83' '51' '46' '50' '66' '44'
#  '79' '47' '82' '116' '104' '118' '105' '120' '112' '92' '93' '49' '103'
#  '91' '94' '89' '106-111' '142-151' '106' '100' '110' '125' '97' '113'
#  '42' '98' '45' '56-60' '109' '99' '121' '140' '96' '114' '126' '123'
#  '161' '128' '107' '60-67' '108' '101' '43' '62-100' '63-65' '62-65'
#  '74-78' '66-68' '60-62' '68-70' '77-80' '75-78' '77-78' '74-76' '115-130'
#  '116-132' '106-112' '110-115' '86-88' '75-80' '84-85' '55-56' '54-57'
#  '51-58' '71-75' '72-74' '80-140' '78-80' '75-79' '79-80' '63-66' '80-86'
#  '69-70' '95-97' '76-78' '68-72' '82-92' '73-79' '75-92' '75-85' '90-92'
#  '90-110' '108-140' '130-140' '48-52' '52-62' '55-62' '62-66' '68-74'
#  '70-78' '78-82' '97-103' '110-118' '62-68' '122' '111' '74, 75' '102'
#  '148' '131' '41' '115' '150' '139' '144' '74-82' '64-67' '81-82' '39'
#  '40' '130' '124' '160' '67-75' '82-98' '81-98' '116-130' '136' '58-73'
#  '74-75' '146' '182' '68-71' '60-63' '63-64' '73-75' '70-72' '59-60'
#  '54-55' '51-53' '70-74' '80-87' '82-85' '88-96' '80-82' '75-76' '80-85'
#  '73-74' '53-58' '74-77' '38' '163' '135' '127' '37' '154' '117' '138'
#  '71-74' '58-62' '70-76' '98-103' '92-96' '77-82' '90-102' '63-68' '63-71'
#  '90-95' '75-83' '77-79' '64-73' '93-100' '98-102' '67-70' '68-76' '62-70'
#  '74-83' '82-120' '74-86' '134' '51-52' '109-125' '30' '62-64' '65-72'
#  '53-55' '84-88' '81-83' '75-77' '62-63' '64-66' '25' '33' '119' '34' '35'
#  '74-80' '106-110' '106-108' '95-98' '90-93' '85-90' '72-75' '48-54'
#  '54-56' '54-60' '72-76' '75-81' '85-87' '86-94' '61-65' '84-86' '78-79'
#  '65-67' '56-62' '70-82' '83-104' '48-58' '52-58' '48-82' '36' '28' '190'
#  '145' '32' '80-84' '67-68' '52-55' '69-71' '87-90' '79-81' '80-90'
#  '86-90' '76-80' '56-58' '132' '81-90' '95-105' '88-92' '94-86' '55-57'
#  '60-70' '80-83' '87-92' '73-76' '73-80' '107-118' '88-90' '66-74' '60-65'
#  '54-58' '60-68' '60-75' '82-90' '48-65' '90-100' '52-72' '67-74' '143'
#  '48-57' '142' '31' '82-87' '130-141' '82-86' '82-84' '85-88' '86-92'
#  '81-87' '108-152' '63-67' '68-88' '80-81' '100-105' '95-115' '82-100'
#  '48-50' '59-61' '75-82' '83-90' '83-91' '52-57' '50-62' '62-74' '104-128'
#  '82-89' '133' '89-103' '60-64' '129' '102-106' '141' '68-73' '50-52'
#  '87-91' '76-82' '85-94' '89-92' '56-57' '65-66' '97-105' '52-56'
#  '118-138' '117-125' '95-99' '78-90' '78-85' '72-80' '90-108' '108-112'
#  '48-63' '74-90' '109-141' '59-62' '75-91' '81-84' '88-95' '89-97'
#  '89, 107' '57-61' '126-133' '67-76' '82-93' '166-187' '52-53' '95-100'
#  '49-50' '82-88' '85-92' '75-84' '88-94' '83-86' '64-65' '76-94' '76-77'
#  '90-94' '149-163' '58-64' '53-56' '70-77' '87-93' '83-93' '70-83' '78-81'
#  '105-110' '95-113' '58-68' '52-59' '85-86' '67-72' '59-64' '64-68'
#  '64-69' '91-93' '165-175' '77,5' '69-76' '142-158' '132-145' '137'
#  '97-104' '149' '152' '70-75' '68-75' '91-96' '91-95' '72-79' '68-69'
#  '92-94' '93-104' '62-73' '69-80' '147' '147-163' '102, 105' '57-63'
#  '48-49' '78-103' '104-105' '165' '94-103' '130-133' '125-129' '67-69'
#  '105-113' '67, 72' '140-142' '127-129' '135-140' '119-125' '180'
#  '115-120' '66-73' '92-95' '77-85' '159-163' '55-58' '107-136' '158-168'
#  '67, 71' '132-135' '76, 83' '95-110' '99-101' '60-66' '125-127' '175'
#  '105-114' '98-105' '68, 88' '167' '80, 86' '62-69' '178' '198' '92-97'
#  '66-70' '76-81' '63-70' '65-71' '69-77' '58, 68' '210-218' '69-75'
#  '105-132' '151' '68, 80' '54-64' '156' '78, 80' '63, 66' '67, 69'
#  '100, 104' '158' '86, 90' '170' '84-96' '64-75' '77-81' '88-91' '100-104'
#  '57-67' '95-103' '104-107' '79-82' '61-67' '73-77' '101-125' '49-53'
#  '155-160' '55-59' '66-76' '62, 67' '155' '70-84' '95-102' '75-89' '90-97'
#  '89-96' '105-111' '91-94' '85-89' '90-96' '83-88' '81-86' '83-87' '65-70'
#  '79-86' '71-77' '70-87' '81-85' '58-63']

# %%
## As we can see there in some rows range of weight is given and the dtype of weight and height is object we will convert
## it into numerict value
def clean_and_convert(column):
    def convert_range(value):
        # Ensure the value is treated as a string
        value = str(value)
        if '-' in value:  # Check for a range
            low, high = map(float, value.split('-'))
            return (low + high) / 2
        elif value.replace('.', '', 1).isdigit():  # Check if it’s a single numeric value
            return float(value)
        return None  # For values that cannot be converted

    # Apply the function and convert to numeric
    return pd.to_numeric(column.apply(convert_range), errors='coerce')

# Apply the function to 'Height' and 'Weight' columns
df_cleaned['Height'] = clean_and_convert(df_cleaned['Height'])
df_cleaned['Weight'] = clean_and_convert(df_cleaned['Weight'])

## Cheking unique value in weight and height
print("Height:", df_cleaned['Height'].unique())
print("Weight:", df_cleaned['Weight'].unique())

print("Dataset Information:")
df_cleaned.info()
# Out:
# Height: [ nan 157. 159. 175. 181. 167. 155. 168. 185. 170. 173. 166. 147. 160.
#  165. 180. 171. 153. 183. 172. 163. 176. 184. 169. 177. 178. 182. 162.
#  174. 158. 156. 195. 164. 150. 152. 139. 186. 161. 154. 179. 189. 187.
#  191. 194. 190. 192. 193. 151. 188. 197. 196. 198. 204. 200. 201. 206.
#  212. 213. 148. 130. 199. 132. 202. 145. 208. 203. 210. 216. 207. 205.
#  209. 149. 223. 143. 136. 146. 218. 137. 142. 220. 140. 144. 141. 135.
#  214. 138. 211. 217. 127. 128. 221. 215. 226. 219. 133.]
# Weight: [  nan  48.   54.   76.   80.   61.   55.   68.   73.   75.   85.   84.
#   56.   63.   52.   87.   67.   57.   65.   74.   70.   64.   58.   71.
#   59.   60.   77.   95.   62.   86.   78.   81.   69.   72.   90.   88.
#   53.   83.   51.   46.   50.   66.   44.   79.   47.   82.  116.  104.
#  118.  105.  120.  112.   92.   93.   49.  103.   91.   94.   89.  108.5
#  146.5 106.  100.  110.  125.   97.  113.   42.   98.   45.  109.   99.
#  121.  140.   96.  114.  126.  123.  161.  128.  107.   63.5 108.  101.
#   43.   78.5  76.5  77.5 122.5 124.  112.5  84.5  55.5  54.5  79.5  64.5
#   69.5  83.5 135.   58.5 122.  111.  102.  148.  131.   41.  115.  150.
#  139.  144.   65.5  81.5  39.   40.  130.  160.   89.5 136.   74.5 146.
#  182.   61.5  59.5  75.5  82.5  73.5  38.  163.  127.   37.  154.  117.
#  138.   72.5 100.5  92.5  68.5  96.5 134.   51.5  30.   62.5  25.   33.
#  119.   34.   35.   91.5  87.5  93.5  36.   28.  190.  145.   32.   67.5
#   53.5  88.5 132.   85.5  56.5  70.5 143.   52.5 142.   31.  135.5  86.5
#   80.5 102.5 133.  129.  141.   90.5  60.5 129.5  71.5 176.5  97.5  49.5
#  156.  107.5  66.5 170.  138.5 137.  149.  152.   98.5 147.  155.   48.5
#  104.5 165.  131.5 137.5 180.  117.5 121.5 133.5 175.  109.5 101.5 167.
#  178.  198.   94.5 214.  118.5 151.  158.  105.5 157.5]
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199419 entries, 0 to 213230
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Games        199419 non-null  object
#  1   edition_id   199419 non-null  object
#  2   NOC          199419 non-null  object
#  3   Sport        199419 non-null  object
#  4   Event        199419 non-null  object
#  5   result_id    199419 non-null  float64
#  6   Name         199419 non-null  object
#  7   athlete_id   199419 non-null  object
#  8   pos          199419 non-null  object
#  9   Medal        27901 non-null   object
#  10  isTeamSport  199419 non-null  object
#  11  Height       177915 non-null  float64
#  12  Weight       177875 non-null  float64
#  13  Born         199419 non-null  object
#  14  Country      199419 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 24.3+ MB

# %%
# Missing Data Handling.
missing_data_percentage = (df_cleaned.isnull().sum() / len(df)) * 100
print("Missing Data Percentage in each Column:\n", missing_data_percentage)
# Out:
# Missing Data Percentage in each Column:
#  Games           0.000000
# edition_id      0.000000
# NOC             0.000000
# Sport           0.000000
# Event           0.000000
# result_id       0.000000
# Name            0.000000
# athlete_id      0.000000
# pos             0.000000
# Medal          80.437647
# isTeamSport     0.000000
# Height         10.084838
# Weight         10.103597
# Born            0.000000
# Country         0.000000
# dtype: float64

# %%
## Cleaning the data and handling missing values

## replacing the nan value in height and weight with median according to there sports
# Group by 'Sport' and calculate the median height for each sport
median_height_by_sport = df_cleaned.groupby('Sport')['Height'].transform('median')

# Replace NaN values in 'Height' with the median height of their respective sport
df_cleaned['Height'].fillna(median_height_by_sport)

# Group by 'Sport' and calculate the median weight for each sport
median_weight_by_sport = df_cleaned.groupby('Sport')['Weight'].transform('median')

# Replace NaN values in 'Weight' with the median weight of their respective sport
df_cleaned['Weight'].fillna(median_weight_by_sport)

## Replacing the nan value in medal with no Medal
df_cleaned['Medal'] = df_cleaned['Medal'].fillna('No Medal')

## Checking nan value
print(df_cleaned.isnull().sum())
# Out:
# Games              0
# edition_id         0
# NOC                0
# Sport              0
# Event              0
# result_id          0
# Name               0
# athlete_id         0
# pos                0
# Medal              0
# isTeamSport        0
# Height         21504
# Weight         21544
# Born               0
# Country            0
# dtype: int64

# %%
df_cleaned=df_cleaned.dropna(subset=['Height','Weight'])
print(df_cleaned.isnull().sum())
print(df_cleaned.shape)

# Save the cleaned DataFrame
df_cleaned.to_csv('Cleaned_Olympic_Athlete_Event_Results.csv', index=False)
# Out:
# Games          0
# edition_id     0
# NOC            0
# Sport          0
# Event          0
# result_id      0
# Name           0
# athlete_id     0
# pos            0
# Medal          0
# isTeamSport    0
# Height         0
# Weight         0
# Born           0
# Country        0
# dtype: int64
# (177875, 15)

# %%
## addig new column in dataframe
## Adding age of an athelete and and bmi from height and weight

## Age
# Step 1: Extract the Olympic year
df_cleaned['Olympic_Year'] = df_cleaned['Games'].str.extract(r'(\d{4})')[0].astype(float)

# Step 2: Clean and convert the 'Born' column to datetime
df_cleaned['Born'] = pd.to_datetime(df_cleaned['Born'], format='%d-%m-%Y', errors='coerce')

# Step 3: Extract the birth year
df_cleaned['Birth_Year'] = df_cleaned['Born'].dt.year.astype(float)

# Step 4: Calculate age by subtracting birth year from Olympic year
df_cleaned['Age'] = df_cleaned['Olympic_Year'] - df_cleaned['Birth_Year']

# Step 5: Calculating BMI
df_cleaned['BMI'] = df_cleaned['Weight'] / ((df_cleaned['Height']/100) ** 2)

# Step 6: Remove rows with negative ages
df_cleaned = df_cleaned[df_cleaned['Age'] >= 0]

print(df_cleaned.head)
# Out:
# <bound method NDFrame.head of                        Games edition_id  NOC      Sport  \
# 2       1972 Summer Olympics         18  BEN     Boxing
# 3       1972 Summer Olympics         18  BEN     Boxing
# 12      1972 Summer Olympics         18  BAR  Athletics
# 13      1972 Summer Olympics         18  BAR  Athletics
# 17      1972 Summer Olympics         18  BAR  Athletics
# ...                      ...        ...  ...        ...
# 213222  2022 Winter Olympics         62  ROU  Bobsleigh
# 213223  2022 Winter Olympics         62  GER  Bobsleigh
# 213224  2022 Winter Olympics         62  AUT  Bobsleigh
# 213228  2022 Winter Olympics         62  KOR  Bobsleigh
# 213229  2022 Winter Olympics         62  JAM  Bobsleigh
#
#                              Event   result_id                        Name  \
# 2             Light-Flyweight, Men     24001.0         Meriga Salou Seriki
# 3                Bantamweight, Men     24081.0              Leopold Agbazo
# 12                  Decathlon, Men     61311.0             Clifford Brooks
# 13               100 metres, Women     61396.0        Freida Nicholls-Davy
# 17      4 à400 metres Relay, Women     61484.0                 Lorna Forde
# ...                            ...         ...                         ...
# 213222              Monobob, Women  19019671.0               Andreea Grecu
# 213223              Monobob, Women  19019671.0             Mariama Jamanka
# 213224              Monobob, Women  19019671.0                 Kati Beierl
# 213228              Monobob, Women  19019671.0                  Kim Yu-Ran
# 213229              Monobob, Women  19019671.0  Jazmine Fenlator-Victorian
#
#        athlete_id        pos     Medal isTeamSport  Height  Weight       Born  \
# 2            1692         17  No Medal       FALSE   157.0    48.0 1953-04-08
# 3            1691         33  No Medal       FALSE   159.0    54.0 1945-01-25
# 12          65066        DNF  No Medal       FALSE   181.0    80.0 1944-08-19
# 13          65060  7 h3 r1/4  No Medal       FALSE   167.0    61.0 1950-03-13
# 17          65058  7 h1 r1/2  No Medal        TRUE   155.0    55.0 1952-06-24
# ...           ...        ...       ...         ...     ...     ...        ...
# 213222     128289         12  No Medal       FALSE   180.0    74.0 1994-01-10
# 213223     137253         13  No Medal       FALSE   169.0    75.0 1990-08-23
# 213224     136713         14  No Medal       FALSE   171.0    73.0 1993-08-16
# 213228     137542         18  No Medal       FALSE   170.0    78.0 1992-04-23
# 213229     128682         19  No Medal       FALSE   175.0    76.5 1985-08-29
#
#             Country  Olympic_Year  Birth_Year   Age        BMI
# 2             Benin        1972.0      1953.0  19.0  19.473407
# 3             Benin        1972.0      1945.0  27.0  21.359915
# 12         Barbados        1972.0      1944.0  28.0  24.419279
# 13         Barbados        1972.0      1950.0  22.0  21.872423
# 17         Barbados        1972.0      1952.0  20.0  22.892820
# ...             ...           ...         ...   ...        ...
# 213222      Romania        2022.0      1994.0  28.0  22.839506
# 213223      Germany        2022.0      1990.0  32.0  26.259585
# 213224      Austria        2022.0      1993.0  29.0  24.964946
# 213228  South Korea        2022.0      1992.0  30.0  26.989619
# 213229      Jamaica        2022.0      1985.0  37.0  24.979592
#
# [177668 rows x 19 columns]>

# %%
## Scaling the columns like age,height,weight,and bmi

from sklearn.preprocessing import StandardScaler

# Create a StandardScaler instance
scaler = StandardScaler()

# Scale the features and create new columns for scaled values
df_cleaned[['Scaled_Height', 'Scaled_Weight', 'Scaled_BMI', 'Scaled_Age']] = scaler.fit_transform(
    df_cleaned[['Height', 'Weight', 'BMI', 'Age']]
)

# Display to confirm new columns are created
print(df_cleaned[['Height','Scaled_Height', 'Weight','Scaled_Weight' ,'BMI','Scaled_BMI','Age', 'Scaled_Age']].head())

df_cleaned.to_csv('Scaled_Olympic_Athlete_Event_Results.csv', index=False)
df_scaled=pd.read_csv('Scaled_Olympic_Athlete_Event_Results.csv')
# Out:
#     Height  Scaled_Height  Weight  Scaled_Weight        BMI  Scaled_BMI   Age  \
# 2    157.0      -1.739702    48.0      -1.552801  19.473407   -1.100296  19.0
# 3    159.0      -1.553049    54.0      -1.144047  21.359915   -0.464230  27.0
# 12   181.0       0.500142    80.0       0.627221  24.419279    0.567282  28.0
# 13   167.0      -0.806434    61.0      -0.667167  21.872423   -0.291430  22.0
# 17   155.0      -1.926356    55.0      -1.075921  22.892820    0.052613  20.0
#
#     Scaled_Age
# 2    -1.244627
# 3     0.238887
# 12    0.424326
# 13   -0.688309
# 17   -1.059188
# <ipython-input-9-697c6e1e9a05>:17: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_scaled=pd.read_csv('Scaled_Olympic_Athlete_Event_Results.csv')

# %%
print("Medal" in df_scaled.columns)

print(df_scaled['Medal'].unique())
# Out:
# True
# ['No Medal' 'Silver' 'Bronze' 'Gold']

# %%
# Map the 'Medal' column: 1 for "Gold", "Silver", "Bronze" and 0 for "No Medal"
df_scaled['Medal_Indicator'] = df_scaled['Medal'].apply(lambda x: 0 if x == "No Medal" else 1)

# %%
print(df_scaled.columns)
# Out:
# Index(['Games', 'edition_id', 'NOC', 'Sport', 'Event', 'result_id', 'Name',
#        'athlete_id', 'pos', 'Medal', 'isTeamSport', 'Height', 'Weight', 'Born',
#        'Country', 'Olympic_Year', 'Birth_Year', 'Age', 'BMI', 'Scaled_Height',
#        'Scaled_Weight', 'Scaled_BMI', 'Scaled_Age', 'Medal_Indicator'],
#       dtype='object')

# %%
df_scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177668 entries, 0 to 177667
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Games            177668 non-null  object
#  1   edition_id       177668 non-null  int64
#  2   NOC              177668 non-null  object
#  3   Sport            177668 non-null  object
#  4   Event            177668 non-null  object
#  5   result_id        177668 non-null  float64
#  6   Name             177668 non-null  object
#  7   athlete_id       177668 non-null  object
#  8   pos              177668 non-null  object
#  9   Medal            177668 non-null  object
#  10  isTeamSport      177668 non-null  bool
#  11  Height           177668 non-null  float64
#  12  Weight           177668 non-null  float64
#  13  Born             177668 non-null  object
#  14  Country          177668 non-null  object
#  15  Olympic_Year     177668 non-null  float64
#  16  Birth_Year       177668 non-null  float64
#  17  Age              177668 non-null  float64
#  18  BMI              177668 non-null  float64
#  19  Scaled_Height    177668 non-null  float64
#  20  Scaled_Weight    177668 non-null  float64
#  21  Scaled_BMI       177668 non-null  float64
#  22  Scaled_Age       177668 non-null  float64
#  23  Medal_Indicator  177668 non-null  int64
# dtypes: bool(1), float64(11), int64(2), object(10)
# memory usage: 31.3+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplots for outlier detection for numerical features
numerical_features = ['Scaled_Height', 'Scaled_Weight', 'Scaled_BMI', 'Scaled_Age']

plt.figure(figsize=(12, 8))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_scaled[feature])
    plt.title(f'Boxplot of {feature}')
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# You can also use a scatter plot to visualize outliers for pairs of features
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Scaled_Height', y='Scaled_Weight', data=df_scaled)
plt.title('Scatter Plot of Height vs. Weight')
plt.xlabel('Scaled Height')
plt.ylabel('Scaled Weight')
plt.show()

# Histogram for outlier detection for numerical features
plt.figure(figsize=(12, 8))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    sns.histplot(df_scaled[feature], kde=True)
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %%
# Define a function to cap outliers using IQR method
def cap_outliers_iqr(df, column, factor=1.5):
  Q1 = df[column].quantile(0.25)
  Q3 = df[column].quantile(0.75)
  IQR = Q3 - Q1
  lower_bound = Q1 - factor * IQR
  upper_bound = Q3 + factor * IQR
  df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
  return df


# Apply capping to the numerical features
for feature in ['Scaled_Height', 'Scaled_Weight', 'Scaled_BMI', 'Scaled_Age']:
    df_scaled = cap_outliers_iqr(df_scaled, feature)

# Display the updated boxplots
plt.figure(figsize=(12, 8))
for i, feature in enumerate(numerical_features):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(x=df_scaled[feature])
    plt.title(f'Boxplot of {feature} (After Capping)')
    plt.xlabel(feature)

plt.tight_layout()
plt.show()

# %%
## EDA
import matplotlib.pyplot as plt
import seaborn as sns

top_countries = df_scaled[df_scaled['Medal'] != 'No Medal']['Country'].value_counts().head(10)
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.xticks(rotation=90)
plt.title('Top 10 Countries by Medal Count')
plt.xlabel('Country')
plt.ylabel('Medal Count')
plt.show()

# %%
# Medal distribution by sport (Top 10 sports by medal count)
plt.figure(figsize=(10, 6))
top_sports = df_scaled[df_scaled['Medal'] != 'No Medal']['Sport'].value_counts().head(10)
sns.barplot(x=top_sports.index, y=top_sports.values, palette='plasma')
plt.title('Top 10 Sports by Medal Count')
plt.xlabel('Sport')
plt.ylabel('Medal Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-18-ed8f79c657b2>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_sports.index, y=top_sports.values, palette='plasma')

# %%
# Participation by sport over time (Top 5 sports with most participation)
top_sports_participation = df['Sport'].value_counts().head(5).index
df_top_sports = df_scaled[df_scaled['Sport'].isin(top_sports_participation)]
plt.figure(figsize=(12, 8))
sns.countplot(data=df_top_sports, x='Olympic_Year', hue='Sport', palette='Set2')
plt.title('Top 5 Sports Participation Over Time')
plt.xlabel('Year')
plt.ylabel('Participation Count')
plt.xticks(rotation=45)
plt.legend(title='Sport')
plt.show()

# %%
# This graph is to plot Age vs Bmi for wrestler for top 5 countries

# Step 1: Filter data for wrestling and where a medal was won
wrestling_medal_data = df_scaled[(df_scaled['Sport'] == 'Wrestling') & (df_scaled['Medal'] != 'No Medal')]

# Step 2: Get the top 5 countries in wrestling based on the number of medals won
top_5_wrestling_countries = wrestling_medal_data['Country'].value_counts().nlargest(5).index

# Step 3: Filter the original wrestling data to only include these top 5 countries
top_5_wrestling_data = wrestling_medal_data[wrestling_medal_data['Country'].isin(top_5_wrestling_countries)]

# Step 4: Plot Age vs. BMI for wrestlers from the top 5 countries
plt.figure(figsize=(12, 8))
sns.scatterplot(data=top_5_wrestling_data, x='Age', y='BMI', hue='Country', palette='tab10')
plt.title('Scatter Plot of Age vs. BMI for Wrestlers by Top 5 Countries with Most Medals')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


## WE can do more Data Visualization Tecnique but there are many countries and many sports so it is not possible to show all tecnique

# %%
#Logistic Regression
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    mean_squared_error,
    mean_absolute_error,
    confusion_matrix
)

# Group the data by sport and perform separate analysis for each sport
for sport in df_scaled['Sport'].unique():
    df_sport = df_scaled[df_scaled['Sport'] == sport]
    if df_sport.shape[0] > 0:  # Check if the sport group has enough data
        # Select relevant features (e.g., Scaled_BMI, Scaled_Age, Country) and target variable
        X = df_sport[['Scaled_BMI', 'Scaled_Age', 'Country']]

        # One hot encode the country column
        X = pd.get_dummies(X, columns=['Country'], prefix=['Country'])
        y = df_sport['Medal_Indicator']

        # Check if there are at least two classes in the target variable
        if len(np.unique(y)) > 1:
            minority_class_size = np.min(np.bincount(y))
            k_neighbors = min(5, minority_class_size - 1) if minority_class_size > 1 else 1
            smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
            X_resampled, y_resampled = smote.fit_resample(X, y)

            # Split data into training and testing sets
            X_train, X_test, y_train, y_test = train_test_split(
                X_resampled, y_resampled, test_size=0.2, random_state=42
            )

            # Train a logistic regression model
            model = LogisticRegression()
            model.fit(X_train, y_train)

            # Make predictions on the test set and the training set
            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            # Evaluate the model
            accuracy = accuracy_score(y_test, y_test_pred)

            # Calculate MSE, MAE, and R2 for training and testing sets
            train_mse = mean_squared_error(y_train, y_train_pred)
            train_mae = mean_absolute_error(y_train, y_train_pred)
            test_mse = mean_squared_error(y_test, y_test_pred)
            test_mae = mean_absolute_error(y_test, y_test_pred)

            # Calculate confusion matrix for the test set
            conf_matrix = confusion_matrix(y_test, y_test_pred)

            # Print the evaluation results
            print(f"Sport: {sport}")
            print(f"Accuracy: {accuracy}")
            print(f"Training MSE: {train_mse}")
            print(f"Testing MSE: {test_mse}")
            print(f"Training MAE: {train_mae}")
            print(f"Testing MAE: {test_mae}")
            print("Confusion Matrix (Test Set):")
            print(conf_matrix)
            print("Classification Report (Test Set):")
            print(classification_report(y_test, y_test_pred))
            print("\n" + "-"*50 + "\n")
# Out:
# Sport: Boxing
# Accuracy: 0.7569856054191363
# Training MSE: 0.21944503283202713
# Testing MSE: 0.24301439458086369
# Training MAE: 0.21944503283202713
# Testing MAE: 0.24301439458086369
# Confusion Matrix (Test Set):
# [[387 211]
#  [ 76 507]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.65      0.73       598
#            1       0.71      0.87      0.78       583
#
#     accuracy                           0.76      1181
#    macro avg       0.77      0.76      0.75      1181
# weighted avg       0.77      0.76      0.75      1181
#
#
# --------------------------------------------------
#
# Sport: Athletics
# Accuracy: 0.7437813720022309
# Training MSE: 0.256630504504002
# Testing MSE: 0.2562186279977691
# Training MAE: 0.256630504504002
# Testing MAE: 0.2562186279977691
# Confusion Matrix (Test Set):
# [[3256 1276]
#  [1021 3412]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.76      0.72      0.74      4532
#            1       0.73      0.77      0.75      4433
#
#     accuracy                           0.74      8965
#    macro avg       0.74      0.74      0.74      8965
# weighted avg       0.74      0.74      0.74      8965
#
#
# --------------------------------------------------
#
# Sport: Cycling Road
# Accuracy: 0.7886728655959425
# Training MSE: 0.1957302895793701
# Testing MSE: 0.21132713440405748
# Training MAE: 0.1957302895793701
# Testing MAE: 0.21132713440405748
# Confusion Matrix (Test Set):
# [[430 174]
#  [ 76 503]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77       604
#            1       0.74      0.87      0.80       579
#
#     accuracy                           0.79      1183
#    macro avg       0.80      0.79      0.79      1183
# weighted avg       0.80      0.79      0.79      1183
#
#
# --------------------------------------------------
#
# Sport: Cycling Track
# Accuracy: 0.7291414752116082
# Training MSE: 0.24780635400907716
# Testing MSE: 0.2708585247883918
# Training MAE: 0.24780635400907716
# Testing MAE: 0.2708585247883918
# Confusion Matrix (Test Set):
# [[287 145]
#  [ 79 316]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.78      0.66      0.72       432
#            1       0.69      0.80      0.74       395
#
#     accuracy                           0.73       827
#    macro avg       0.73      0.73      0.73       827
# weighted avg       0.74      0.73      0.73       827
#
#
# --------------------------------------------------
#
# Sport: Shooting
# Accuracy: 0.7692307692307693
# Training MSE: 0.2402085747392816
# Testing MSE: 0.23076923076923078
# Training MAE: 0.2402085747392816
# Testing MAE: 0.23076923076923078
# Confusion Matrix (Test Set):
# [[776 299]
#  [199 884]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76      1075
#            1       0.75      0.82      0.78      1083
#
#     accuracy                           0.77      2158
#    macro avg       0.77      0.77      0.77      2158
# weighted avg       0.77      0.77      0.77      2158
#
#
# --------------------------------------------------
#
# Sport: Weightlifting
# Accuracy: 0.779467680608365
# Training MSE: 0.22518236600063432
# Testing MSE: 0.22053231939163498
# Training MAE: 0.22518236600063432
# Testing MAE: 0.22053231939163498
# Confusion Matrix (Test Set):
# [[304 107]
#  [ 67 311]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       411
#            1       0.74      0.82      0.78       378
#
#     accuracy                           0.78       789
#    macro avg       0.78      0.78      0.78       789
# weighted avg       0.78      0.78      0.78       789
#
#
# --------------------------------------------------
#
# Sport: Wrestling
# Accuracy: 0.7041825095057034
# Training MSE: 0.29758509222285606
# Testing MSE: 0.29581749049429656
# Training MAE: 0.29758509222285606
# Testing MAE: 0.29581749049429656
# Confusion Matrix (Test Set):
# [[452 219]
#  [170 474]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.73      0.67      0.70       671
#            1       0.68      0.74      0.71       644
#
#     accuracy                           0.70      1315
#    macro avg       0.71      0.70      0.70      1315
# weighted avg       0.71      0.70      0.70      1315
#
#
# --------------------------------------------------
#
# Sport: Swimming
# Accuracy: 0.7743826612186889
# Training MSE: 0.2316883578376938
# Testing MSE: 0.22561733878131107
# Training MAE: 0.2316883578376938
# Testing MAE: 0.22561733878131107
# Confusion Matrix (Test Set):
# [[2178  653]
#  [ 617 2181]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77      2831
#            1       0.77      0.78      0.77      2798
#
#     accuracy                           0.77      5629
#    macro avg       0.77      0.77      0.77      5629
# weighted avg       0.77      0.77      0.77      5629
#
#
# --------------------------------------------------
#
# Sport: Equestrian Jumping
# Accuracy: 0.771484375
# Training MSE: 0.21484375
# Testing MSE: 0.228515625
# Training MAE: 0.21484375
# Testing MAE: 0.228515625
# Confusion Matrix (Test Set):
# [[197  67]
#  [ 50 198]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77       264
#            1       0.75      0.80      0.77       248
#
#     accuracy                           0.77       512
#    macro avg       0.77      0.77      0.77       512
# weighted avg       0.77      0.77      0.77       512
#
#
# --------------------------------------------------
#
# Sport: Rowing
# Accuracy: 0.6833514689880305
# Training MSE: 0.3260337323177367
# Testing MSE: 0.31664853101196955
# Training MAE: 0.3260337323177367
# Testing MAE: 0.31664853101196955
# Confusion Matrix (Test Set):
# [[527 392]
#  [190 729]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.74      0.57      0.64       919
#            1       0.65      0.79      0.71       919
#
#     accuracy                           0.68      1838
#    macro avg       0.69      0.68      0.68      1838
# weighted avg       0.69      0.68      0.68      1838
#
#
# --------------------------------------------------
#
# Sport: Sailing
# Accuracy: 0.6920236336779911
# Training MSE: 0.2784552845528455
# Testing MSE: 0.30797636632200887
# Training MAE: 0.2784552845528455
# Testing MAE: 0.30797636632200887
# Confusion Matrix (Test Set):
# [[425 254]
#  [163 512]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.72      0.63      0.67       679
#            1       0.67      0.76      0.71       675
#
#     accuracy                           0.69      1354
#    macro avg       0.70      0.69      0.69      1354
# weighted avg       0.70      0.69      0.69      1354
#
#
# --------------------------------------------------
#
# Sport: Canoe Sprint
# Accuracy: 0.7061538461538461
# Training MSE: 0.27972297037322047
# Testing MSE: 0.29384615384615387
# Training MAE: 0.27972297037322047
# Testing MAE: 0.29384615384615387
# Confusion Matrix (Test Set):
# [[443 213]
#  [169 475]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       656
#            1       0.69      0.74      0.71       644
#
#     accuracy                           0.71      1300
#    macro avg       0.71      0.71      0.71      1300
# weighted avg       0.71      0.71      0.71      1300
#
#
# --------------------------------------------------
#
# Sport: Judo
# Accuracy: 0.7664298401420959
# Training MSE: 0.21822222222222223
# Testing MSE: 0.23357015985790408
# Training MAE: 0.21822222222222223
# Testing MAE: 0.23357015985790408
# Confusion Matrix (Test Set):
# [[391 179]
#  [ 84 472]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75       570
#            1       0.73      0.85      0.78       556
#
#     accuracy                           0.77      1126
#    macro avg       0.77      0.77      0.77      1126
# weighted avg       0.77      0.77      0.77      1126
#
#
# --------------------------------------------------
#
# Sport: Artistic Gymnastics
# Accuracy: 0.7662974009373669
# Training MSE: 0.22858968896463572
# Testing MSE: 0.23370259906263316
# Training MAE: 0.22858968896463572
# Testing MAE: 0.23370259906263316
# Confusion Matrix (Test Set):
# [[1540  812]
#  [ 285 2057]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.65      0.74      2352
#            1       0.72      0.88      0.79      2342
#
#     accuracy                           0.77      4694
#    macro avg       0.78      0.77      0.76      4694
# weighted avg       0.78      0.77      0.76      4694
#
#
# --------------------------------------------------
#
# Sport: Volleyball
# Accuracy: 0.7288941736028538
# Training MSE: 0.271050282653972
# Testing MSE: 0.27110582639714625
# Training MAE: 0.271050282653972
# Testing MAE: 0.27110582639714625
# Confusion Matrix (Test Set):
# [[264 167]
#  [ 61 349]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.81      0.61      0.70       431
#            1       0.68      0.85      0.75       410
#
#     accuracy                           0.73       841
#    macro avg       0.74      0.73      0.73       841
# weighted avg       0.75      0.73      0.73       841
#
#
# --------------------------------------------------
#
# Sport: Diving
# Accuracy: 0.7409420289855072
# Training MSE: 0.22327898550724637
# Testing MSE: 0.25905797101449274
# Training MAE: 0.22327898550724637
# Testing MAE: 0.25905797101449274
# Confusion Matrix (Test Set):
# [[208  69]
#  [ 74 201]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.74      0.75      0.74       277
#            1       0.74      0.73      0.74       275
#
#     accuracy                           0.74       552
#    macro avg       0.74      0.74      0.74       552
# weighted avg       0.74      0.74      0.74       552
#
#
# --------------------------------------------------
#
# Sport: Football
# Accuracy: 0.797847809377402
# Training MSE: 0.19630840223034032
# Testing MSE: 0.202152190622598
# Training MAE: 0.19630840223034032
# Testing MAE: 0.202152190622598
# Confusion Matrix (Test Set):
# [[517 145]
#  [118 521]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80       662
#            1       0.78      0.82      0.80       639
#
#     accuracy                           0.80      1301
#    macro avg       0.80      0.80      0.80      1301
# weighted avg       0.80      0.80      0.80      1301
#
#
# --------------------------------------------------
#
# Sport: Canoe Slalom
# Accuracy: 0.7692307692307693
# Training MSE: 0.22297297297297297
# Testing MSE: 0.23076923076923078
# Training MAE: 0.22297297297297297
# Testing MAE: 0.23076923076923078
# Confusion Matrix (Test Set):
# [[ 88  48]
#  [ 12 112]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75       136
#            1       0.70      0.90      0.79       124
#
#     accuracy                           0.77       260
#    macro avg       0.79      0.78      0.77       260
# weighted avg       0.79      0.77      0.77       260
#
#
# --------------------------------------------------
#
# Sport: Equestrian Dressage
# Accuracy: 0.8013937282229965
# Training MSE: 0.20087336244541484
# Testing MSE: 0.1986062717770035
# Training MAE: 0.20087336244541484
# Testing MAE: 0.1986062717770035
# Confusion Matrix (Test Set):
# [[100  37]
#  [ 20 130]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78       137
#            1       0.78      0.87      0.82       150
#
#     accuracy                           0.80       287
#    macro avg       0.81      0.80      0.80       287
# weighted avg       0.80      0.80      0.80       287
#
#
# --------------------------------------------------
#
# Sport: Equestrian Eventing
# Accuracy: 0.8181818181818182
# Training MSE: 0.19156024430871738
# Testing MSE: 0.18181818181818182
# Training MAE: 0.19156024430871738
# Testing MAE: 0.18181818181818182
# Confusion Matrix (Test Set):
# [[168  61]
#  [ 21 201]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80       229
#            1       0.77      0.91      0.83       222
#
#     accuracy                           0.82       451
#    macro avg       0.83      0.82      0.82       451
# weighted avg       0.83      0.82      0.82       451
#
#
# --------------------------------------------------
#
# Sport: Fencing
# Accuracy: 0.7579493835171967
# Training MSE: 0.2606719688362279
# Testing MSE: 0.24205061648280338
# Training MAE: 0.2606719688362279
# Testing MAE: 0.24205061648280338
# Confusion Matrix (Test Set):
# [[563 218]
#  [155 605]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75       781
#            1       0.74      0.80      0.76       760
#
#     accuracy                           0.76      1541
#    macro avg       0.76      0.76      0.76      1541
# weighted avg       0.76      0.76      0.76      1541
#
#
# --------------------------------------------------
#
# Sport: Handball
# Accuracy: 0.7325102880658436
# Training MSE: 0.2507716049382716
# Testing MSE: 0.2674897119341564
# Training MAE: 0.2507716049382716
# Testing MAE: 0.2674897119341564
# Confusion Matrix (Test Set):
# [[268 214]
#  [ 46 444]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.67       482
#            1       0.67      0.91      0.77       490
#
#     accuracy                           0.73       972
#    macro avg       0.76      0.73      0.72       972
# weighted avg       0.76      0.73      0.72       972
#
#
# --------------------------------------------------
#
# Sport: Basketball
# Accuracy: 0.8108108108108109
# Training MSE: 0.1954517516902274
# Testing MSE: 0.1891891891891892
# Training MAE: 0.1954517516902274
# Testing MAE: 0.1891891891891892
# Confusion Matrix (Test Set):
# [[346  86]
#  [ 68 314]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       432
#            1       0.79      0.82      0.80       382
#
#     accuracy                           0.81       814
#    macro avg       0.81      0.81      0.81       814
# weighted avg       0.81      0.81      0.81       814
#
#
# --------------------------------------------------
#
# Sport: Water Polo
# Accuracy: 0.8
# Training MSE: 0.24320063066614112
# Testing MSE: 0.2
# Training MAE: 0.24320063066614112
# Testing MAE: 0.2
# Confusion Matrix (Test Set):
# [[250  75]
#  [ 52 258]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       325
#            1       0.77      0.83      0.80       310
#
#     accuracy                           0.80       635
#    macro avg       0.80      0.80      0.80       635
# weighted avg       0.80      0.80      0.80       635
#
#
# --------------------------------------------------
#
# Sport: Hockey
# Accuracy: 0.7538022813688213
# Training MSE: 0.2656844106463878
# Testing MSE: 0.2461977186311787
# Training MAE: 0.2656844106463878
# Testing MAE: 0.2461977186311787
# Confusion Matrix (Test Set):
# [[352 160]
#  [ 99 441]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.78      0.69      0.73       512
#            1       0.73      0.82      0.77       540
#
#     accuracy                           0.75      1052
#    macro avg       0.76      0.75      0.75      1052
# weighted avg       0.76      0.75      0.75      1052
#
#
# --------------------------------------------------
#
# Sport: Modern Pentathlon
# Accuracy: 0.8413173652694611
# Training MSE: 0.1724137931034483
# Testing MSE: 0.15868263473053892
# Training MAE: 0.1724137931034483
# Testing MAE: 0.15868263473053892
# Confusion Matrix (Test Set):
# [[136  40]
#  [ 13 145]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.84       176
#            1       0.78      0.92      0.85       158
#
#     accuracy                           0.84       334
#    macro avg       0.85      0.85      0.84       334
# weighted avg       0.85      0.84      0.84       334
#
#
# --------------------------------------------------
#
# Sport: Archery
# Accuracy: 0.7840579710144927
# Training MSE: 0.17851959361393324
# Testing MSE: 0.21594202898550724
# Training MAE: 0.17851959361393324
# Testing MAE: 0.21594202898550724
# Confusion Matrix (Test Set):
# [[272  79]
#  [ 70 269]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78       351
#            1       0.77      0.79      0.78       339
#
#     accuracy                           0.78       690
#    macro avg       0.78      0.78      0.78       690
# weighted avg       0.78      0.78      0.78       690
#
#
# --------------------------------------------------
#
# Sport: Speed Skating
# Accuracy: 0.6616438356164384
# Training MSE: 0.34578478409869773
# Testing MSE: 0.33835616438356164
# Training MAE: 0.34578478409869773
# Testing MAE: 0.33835616438356164
# Confusion Matrix (Test Set):
# [[461 294]
#  [200 505]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.70      0.61      0.65       755
#            1       0.63      0.72      0.67       705
#
#     accuracy                           0.66      1460
#    macro avg       0.66      0.66      0.66      1460
# weighted avg       0.67      0.66      0.66      1460
#
#
# --------------------------------------------------
#
# Sport: Alpine Skiing
# Accuracy: 0.7501057082452431
# Training MSE: 0.24891614676958868
# Testing MSE: 0.24989429175475686
# Training MAE: 0.24891614676958868
# Testing MAE: 0.24989429175475686
# Confusion Matrix (Test Set):
# [[ 661  527]
#  [  64 1113]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.56      0.69      1188
#            1       0.68      0.95      0.79      1177
#
#     accuracy                           0.75      2365
#    macro avg       0.80      0.75      0.74      2365
# weighted avg       0.80      0.75      0.74      2365
#
#
# --------------------------------------------------
#
# Sport: Cross Country Skiing
# Accuracy: 0.7930137495354886
# Training MSE: 0.21202267025922142
# Testing MSE: 0.20698625046451133
# Training MAE: 0.21202267025922142
# Testing MAE: 0.20698625046451133
# Confusion Matrix (Test Set):
# [[ 966  410]
#  [ 147 1168]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.78      1376
#            1       0.74      0.89      0.81      1315
#
#     accuracy                           0.79      2691
#    macro avg       0.80      0.80      0.79      2691
# weighted avg       0.81      0.79      0.79      2691
#
#
# --------------------------------------------------
#
# Sport: Biathlon
# Accuracy: 0.8037940379403794
# Training MSE: 0.20775172787640603
# Testing MSE: 0.1962059620596206
# Training MAE: 0.20775172787640603
# Testing MAE: 0.1962059620596206
# Confusion Matrix (Test Set):
# [[715 216]
#  [146 768]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       931
#            1       0.78      0.84      0.81       914
#
#     accuracy                           0.80      1845
#    macro avg       0.81      0.80      0.80      1845
# weighted avg       0.81      0.80      0.80      1845
#
#
# --------------------------------------------------
#
# Sport: Figure Skating
# Accuracy: 0.7650602409638554
# Training MSE: 0.2522613065326633
# Testing MSE: 0.23493975903614459
# Training MAE: 0.2522613065326633
# Testing MAE: 0.23493975903614459
# Confusion Matrix (Test Set):
# [[170  79]
#  [ 38 211]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.68      0.74       249
#            1       0.73      0.85      0.78       249
#
#     accuracy                           0.77       498
#    macro avg       0.77      0.77      0.76       498
# weighted avg       0.77      0.77      0.76       498
#
#
# --------------------------------------------------
#
# Sport: Luge
# Accuracy: 0.8
# Training MSE: 0.20137058513442277
# Testing MSE: 0.2
# Training MAE: 0.20137058513442277
# Testing MAE: 0.2
# Confusion Matrix (Test Set):
# [[180  57]
#  [ 38 200]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.76      0.79       237
#            1       0.78      0.84      0.81       238
#
#     accuracy                           0.80       475
#    macro avg       0.80      0.80      0.80       475
# weighted avg       0.80      0.80      0.80       475
#
#
# --------------------------------------------------
#
# Sport: Nordic Combined
# Accuracy: 0.7209302325581395
# Training MSE: 0.2908855850032321
# Testing MSE: 0.27906976744186046
# Training MAE: 0.2908855850032321
# Testing MAE: 0.27906976744186046
# Confusion Matrix (Test Set):
# [[137  55]
#  [ 53 142]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.72       192
#            1       0.72      0.73      0.72       195
#
#     accuracy                           0.72       387
#    macro avg       0.72      0.72      0.72       387
# weighted avg       0.72      0.72      0.72       387
#
#
# --------------------------------------------------
#
# Sport: Ski Jumping
# Accuracy: 0.7727930535455861
# Training MSE: 0.21317408613825553
# Testing MSE: 0.2272069464544139
# Training MAE: 0.21317408613825553
# Testing MAE: 0.2272069464544139
# Confusion Matrix (Test Set):
# [[233 131]
#  [ 26 301]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.90      0.64      0.75       364
#            1       0.70      0.92      0.79       327
#
#     accuracy                           0.77       691
#    macro avg       0.80      0.78      0.77       691
# weighted avg       0.80      0.77      0.77       691
#
#
# --------------------------------------------------
#
# Sport: Ice Hockey
# Accuracy: 0.8074074074074075
# Training MSE: 0.19757151677299856
# Testing MSE: 0.1925925925925926
# Training MAE: 0.19757151677299856
# Testing MAE: 0.1925925925925926
# Confusion Matrix (Test Set):
# [[403 195]
#  [ 39 578]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.78       598
#            1       0.75      0.94      0.83       617
#
#     accuracy                           0.81      1215
#    macro avg       0.83      0.81      0.80      1215
# weighted avg       0.83      0.81      0.80      1215
#
#
# --------------------------------------------------
#
# Sport: Bobsleigh
# Accuracy: 0.7884362680683311
# Training MSE: 0.21524811041735128
# Testing MSE: 0.21156373193166886
# Training MAE: 0.21524811041735128
# Testing MAE: 0.21156373193166886
# Confusion Matrix (Test Set):
# [[295  87]
#  [ 74 305]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.80      0.77      0.79       382
#            1       0.78      0.80      0.79       379
#
#     accuracy                           0.79       761
#    macro avg       0.79      0.79      0.79       761
# weighted avg       0.79      0.79      0.79       761
#
#
# --------------------------------------------------
#
# Sport: Baseball
# Accuracy: 0.8125
# Training MSE: 0.13534675615212527
# Testing MSE: 0.1875
# Training MAE: 0.13534675615212527
# Testing MAE: 0.1875
# Confusion Matrix (Test Set):
# [[ 71  33]
#  [  9 111]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77       104
#            1       0.77      0.93      0.84       120
#
#     accuracy                           0.81       224
#    macro avg       0.83      0.80      0.81       224
# weighted avg       0.83      0.81      0.81       224
#
#
# --------------------------------------------------
#
# Sport: Tennis
# Accuracy: 0.7728494623655914
# Training MSE: 0.1975806451612903
# Testing MSE: 0.2271505376344086
# Training MAE: 0.1975806451612903
# Testing MAE: 0.2271505376344086
# Confusion Matrix (Test Set):
# [[266 115]
#  [ 54 309]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       381
#            1       0.73      0.85      0.79       363
#
#     accuracy                           0.77       744
#    macro avg       0.78      0.77      0.77       744
# weighted avg       0.78      0.77      0.77       744
#
#
# --------------------------------------------------
#
# Sport: Artistic Swimming
# Accuracy: 0.8403041825095057
# Training MSE: 0.14204003813155386
# Testing MSE: 0.1596958174904943
# Training MAE: 0.14204003813155386
# Testing MAE: 0.1596958174904943
# Confusion Matrix (Test Set):
# [[ 95  38]
#  [  4 126]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82       133
#            1       0.77      0.97      0.86       130
#
#     accuracy                           0.84       263
#    macro avg       0.86      0.84      0.84       263
# weighted avg       0.87      0.84      0.84       263
#
#
# --------------------------------------------------
#
# Sport: Rhythmic Gymnastics
# Accuracy: 0.775609756097561
# Training MSE: 0.1807081807081807
# Testing MSE: 0.22439024390243903
# Training MAE: 0.1807081807081807
# Testing MAE: 0.22439024390243903
# Confusion Matrix (Test Set):
# [[76 27]
#  [19 83]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77       103
#            1       0.75      0.81      0.78       102
#
#     accuracy                           0.78       205
#    macro avg       0.78      0.78      0.78       205
# weighted avg       0.78      0.78      0.78       205
#
#
# --------------------------------------------------
#
# Sport: Table Tennis
# Accuracy: 0.8937125748502994
# Training MSE: 0.10861423220973783
# Testing MSE: 0.1062874251497006
# Training MAE: 0.10861423220973783
# Testing MAE: 0.1062874251497006
# Confusion Matrix (Test Set):
# [[299  61]
#  [ 10 298]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.97      0.83      0.89       360
#            1       0.83      0.97      0.89       308
#
#     accuracy                           0.89       668
#    macro avg       0.90      0.90      0.89       668
# weighted avg       0.90      0.89      0.89       668
#
#
# --------------------------------------------------
#
# Sport: Badminton
# Accuracy: 0.8204081632653061
# Training MSE: 0.177732379979571
# Testing MSE: 0.17959183673469387
# Training MAE: 0.177732379979571
# Testing MAE: 0.17959183673469387
# Confusion Matrix (Test Set):
# [[187  65]
#  [ 23 215]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.74      0.81       252
#            1       0.77      0.90      0.83       238
#
#     accuracy                           0.82       490
#    macro avg       0.83      0.82      0.82       490
# weighted avg       0.83      0.82      0.82       490
#
#
# --------------------------------------------------
#
# Sport: Taekwondo
# Accuracy: 0.8097826086956522
# Training MSE: 0.16393442622950818
# Testing MSE: 0.19021739130434784
# Training MAE: 0.16393442622950818
# Testing MAE: 0.19021739130434784
# Confusion Matrix (Test Set):
# [[69 21]
#  [14 80]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80        90
#            1       0.79      0.85      0.82        94
#
#     accuracy                           0.81       184
#    macro avg       0.81      0.81      0.81       184
# weighted avg       0.81      0.81      0.81       184
#
#
# --------------------------------------------------
#
# Sport: Curling
# Accuracy: 0.7473118279569892
# Training MSE: 0.25
# Testing MSE: 0.25268817204301075
# Training MAE: 0.25
# Testing MAE: 0.25268817204301075
# Confusion Matrix (Test Set):
# [[65 26]
#  [21 74]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73        91
#            1       0.74      0.78      0.76        95
#
#     accuracy                           0.75       186
#    macro avg       0.75      0.75      0.75       186
# weighted avg       0.75      0.75      0.75       186
#
#
# --------------------------------------------------
#
# Sport: Short Track Speed Skating
# Accuracy: 0.7432239657631954
# Training MSE: 0.25258651444880487
# Testing MSE: 0.25677603423680456
# Training MAE: 0.25258651444880487
# Testing MAE: 0.25677603423680456
# Confusion Matrix (Test Set):
# [[244 140]
#  [ 40 277]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.64      0.73       384
#            1       0.66      0.87      0.75       317
#
#     accuracy                           0.74       701
#    macro avg       0.76      0.75      0.74       701
# weighted avg       0.77      0.74      0.74       701
#
#
# --------------------------------------------------
#
# Sport: Freestyle Skiing
# Accuracy: 0.6939655172413793
# Training MSE: 0.3112189859762675
# Testing MSE: 0.30603448275862066
# Training MAE: 0.3112189859762675
# Testing MAE: 0.30603448275862066
# Confusion Matrix (Test Set):
# [[156  89]
#  [ 53 166]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.75      0.64      0.69       245
#            1       0.65      0.76      0.70       219
#
#     accuracy                           0.69       464
#    macro avg       0.70      0.70      0.69       464
# weighted avg       0.70      0.69      0.69       464
#
#
# --------------------------------------------------
#
# Sport: Cycling Mountain Bike
# Accuracy: 0.9075144508670521
# Training MSE: 0.11756168359941944
# Testing MSE: 0.09248554913294797
# Training MAE: 0.11756168359941944
# Testing MAE: 0.09248554913294797
# Confusion Matrix (Test Set):
# [[80  7]
#  [ 9 77]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91        87
#            1       0.92      0.90      0.91        86
#
#     accuracy                           0.91       173
#    macro avg       0.91      0.91      0.91       173
# weighted avg       0.91      0.91      0.91       173
#
#
# --------------------------------------------------
#
# Sport: Softball
# Accuracy: 0.8981481481481481
# Training MSE: 0.0794392523364486
# Testing MSE: 0.10185185185185185
# Training MAE: 0.0794392523364486
# Testing MAE: 0.10185185185185185
# Confusion Matrix (Test Set):
# [[50  2]
#  [ 9 47]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        52
#            1       0.96      0.84      0.90        56
#
#     accuracy                           0.90       108
#    macro avg       0.90      0.90      0.90       108
# weighted avg       0.91      0.90      0.90       108
#
#
# --------------------------------------------------
#
# Sport: Beach Volleyball
# Accuracy: 0.8040201005025126
# Training MSE: 0.1660377358490566
# Testing MSE: 0.19597989949748743
# Training MAE: 0.1660377358490566
# Testing MAE: 0.19597989949748743
# Confusion Matrix (Test Set):
# [[75 25]
#  [14 85]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.75      0.79       100
#            1       0.77      0.86      0.81        99
#
#     accuracy                           0.80       199
#    macro avg       0.81      0.80      0.80       199
# weighted avg       0.81      0.80      0.80       199
#
#
# --------------------------------------------------
#
# Sport: Snowboarding
# Accuracy: 0.6788008565310493
# Training MSE: 0.30455764075067027
# Testing MSE: 0.32119914346895073
# Training MAE: 0.30455764075067027
# Testing MAE: 0.32119914346895073
# Confusion Matrix (Test Set):
# [[153  72]
#  [ 78 164]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.66      0.68      0.67       225
#            1       0.69      0.68      0.69       242
#
#     accuracy                           0.68       467
#    macro avg       0.68      0.68      0.68       467
# weighted avg       0.68      0.68      0.68       467
#
#
# --------------------------------------------------
#
# Sport: Trampolining
# Accuracy: 0.88
# Training MSE: 0.12
# Testing MSE: 0.12
# Training MAE: 0.12
# Testing MAE: 0.12
# Confusion Matrix (Test Set):
# [[20  4]
#  [ 2 24]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87        24
#            1       0.86      0.92      0.89        26
#
#     accuracy                           0.88        50
#    macro avg       0.88      0.88      0.88        50
# weighted avg       0.88      0.88      0.88        50
#
#
# --------------------------------------------------
#
# Sport: Triathlon
# Accuracy: 0.8301886792452831
# Training MSE: 0.14336492890995262
# Testing MSE: 0.16981132075471697
# Training MAE: 0.14336492890995262
# Testing MAE: 0.16981132075471697
# Confusion Matrix (Test Set):
# [[89 27]
#  [ 9 87]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83       116
#            1       0.76      0.91      0.83        96
#
#     accuracy                           0.83       212
#    macro avg       0.84      0.84      0.83       212
# weighted avg       0.84      0.83      0.83       212
#
#
# --------------------------------------------------
#
# Sport: Cycling BMX Racing
# Accuracy: 0.8727272727272727
# Training MSE: 0.14285714285714285
# Testing MSE: 0.12727272727272726
# Training MAE: 0.14285714285714285
# Testing MAE: 0.12727272727272726
# Confusion Matrix (Test Set):
# [[25  4]
#  [ 3 23]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88        29
#            1       0.85      0.88      0.87        26
#
#     accuracy                           0.87        55
#    macro avg       0.87      0.87      0.87        55
# weighted avg       0.87      0.87      0.87        55
#
#
# --------------------------------------------------
#
# Sport: Marathon Swimming
# Accuracy: 0.8448275862068966
# Training MSE: 0.10964912280701754
# Testing MSE: 0.15517241379310345
# Training MAE: 0.10964912280701754
# Testing MAE: 0.15517241379310345
# Confusion Matrix (Test Set):
# [[20  5]
#  [ 4 29]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82        25
#            1       0.85      0.88      0.87        33
#
#     accuracy                           0.84        58
#    macro avg       0.84      0.84      0.84        58
# weighted avg       0.84      0.84      0.84        58
#
#
# --------------------------------------------------
#
# Sport: Skeleton
# Accuracy: 0.8421052631578947
# Training MSE: 0.14096916299559473
# Testing MSE: 0.15789473684210525
# Training MAE: 0.14096916299559473
# Testing MAE: 0.15789473684210525
# Confusion Matrix (Test Set):
# [[19  4]
#  [ 5 29]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81        23
#            1       0.88      0.85      0.87        34
#
#     accuracy                           0.84        57
#    macro avg       0.84      0.84      0.84        57
# weighted avg       0.84      0.84      0.84        57
#
#
# --------------------------------------------------
#
# Sport: Golf
# Accuracy: 0.9444444444444444
# Training MSE: 0.018691588785046728
# Testing MSE: 0.05555555555555555
# Training MAE: 0.018691588785046728
# Testing MAE: 0.05555555555555555
# Confusion Matrix (Test Set):
# [[28  2]
#  [ 1 23]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        30
#            1       0.92      0.96      0.94        24
#
#     accuracy                           0.94        54
#    macro avg       0.94      0.95      0.94        54
# weighted avg       0.95      0.94      0.94        54
#
#
# --------------------------------------------------
#
# Sport: Rugby Sevens
# Accuracy: 0.84251968503937
# Training MSE: 0.16173570019723865
# Testing MSE: 0.15748031496062992
# Training MAE: 0.16173570019723865
# Testing MAE: 0.15748031496062992
# Confusion Matrix (Test Set):
# [[57 15]
#  [ 5 50]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85        72
#            1       0.77      0.91      0.83        55
#
#     accuracy                           0.84       127
#    macro avg       0.84      0.85      0.84       127
# weighted avg       0.85      0.84      0.84       127
#
#
# --------------------------------------------------
#
# Sport: 3x3 Basketball
# Accuracy: 0.0
# Training MSE: 0.0
# Testing MSE: 1.0
# Training MAE: 0.0
# Testing MAE: 1.0
# Confusion Matrix (Test Set):
# [[0 1]
#  [0 0]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.00      0.00      0.00       1.0
# weighted avg       0.00      0.00      0.00       1.0
#
#
# --------------------------------------------------
#
# Sport: Skateboarding
# Accuracy: 0.4
# Training MSE: 0.5294117647058824
# Testing MSE: 0.6
# Training MAE: 0.5294117647058824
# Testing MAE: 0.6
# Confusion Matrix (Test Set):
# [[1 2]
#  [1 1]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         3
#            1       0.33      0.50      0.40         2
#
#     accuracy                           0.40         5
#    macro avg       0.42      0.42      0.40         5
# weighted avg       0.43      0.40      0.40         5
#
#
# --------------------------------------------------
#
# Sport: Surfing
# Accuracy: 0.6666666666666666
# Training MSE: 0.09090909090909091
# Testing MSE: 0.3333333333333333
# Training MAE: 0.09090909090909091
# Testing MAE: 0.3333333333333333
# Confusion Matrix (Test Set):
# [[0 0]
#  [1 2]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.33      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# --------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Random Forrest
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    mean_squared_error,
    mean_absolute_error,
    confusion_matrix
)
import numpy as np
import pandas as pd

# Group the data by sport and perform separate analysis for each sport
for sport in df_scaled['Sport'].unique():
    df_sport = df_scaled[df_scaled['Sport'] == sport]
    if df_sport.shape[0] > 0:
        # Select relevant features (e.g., Scaled_BMI, Scaled_Age, Country) and target variable
        X = df_sport[['Scaled_BMI', 'Scaled_Age', 'Country']]

        # One hot encode the country column
        X = pd.get_dummies(X, columns=['Country'], prefix=['Country'])
        y = df_sport['Medal_Indicator']

        # Check if there are at least two classes in the target variable
        if len(np.unique(y)) > 1:
            minority_class_size = np.min(np.bincount(y))
            k_neighbors = min(5, minority_class_size - 1) if minority_class_size > 1 else 1
            smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
            X_resampled, y_resampled = smote.fit_resample(X, y)

            # Split data into training and testing sets
            X_train, X_test, y_train, y_test = train_test_split(
                X_resampled, y_resampled, test_size=0.2, random_state=42
            )

            # Train a Random Forest model
            model = RandomForestClassifier(random_state=42)
            model.fit(X_train, y_train)

            # Make predictions on both the training and test sets
            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            # Evaluate the model on the training set
            train_mse = mean_squared_error(y_train, y_train_pred)
            train_mae = mean_absolute_error(y_train, y_train_pred)

            # Evaluate the model on the test set
            test_accuracy = accuracy_score(y_test, y_test_pred)
            test_mse = mean_squared_error(y_test, y_test_pred)
            test_mae = mean_absolute_error(y_test, y_test_pred)
            conf_matrix = confusion_matrix(y_test, y_test_pred)

            # Print the evaluation results
            print(f"Sport: {sport}")
            print(f"Test Accuracy: {test_accuracy}")
            print(f"Training MSE: {train_mse}")
            print(f"Testing MSE: {test_mse}")
            print(f"Training MAE: {train_mae}")
            print(f"Testing MAE: {test_mae}")
            print("Confusion Matrix (Test Set):")
            print(conf_matrix)
            print("Classification Report (Test Set):")
            print(classification_report(y_test, y_test_pred))
            print("\n" + "-"*50 + "\n")
# Out:
# Sport: Boxing
# Test Accuracy: 0.8484335309060118
# Training MSE: 0.0012709171785638637
# Testing MSE: 0.15156646909398813
# Training MAE: 0.0012709171785638637
# Testing MAE: 0.15156646909398813
# Confusion Matrix (Test Set):
# [[504  94]
#  [ 85 498]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       598
#            1       0.84      0.85      0.85       583
#
#     accuracy                           0.85      1181
#    macro avg       0.85      0.85      0.85      1181
# weighted avg       0.85      0.85      0.85      1181
#
#
# --------------------------------------------------
#
# Sport: Athletics
# Test Accuracy: 0.8797546012269939
# Training MSE: 0.016342694592408735
# Testing MSE: 0.12024539877300613
# Training MAE: 0.016342694592408735
# Testing MAE: 0.12024539877300613
# Confusion Matrix (Test Set):
# [[4035  497]
#  [ 581 3852]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      4532
#            1       0.89      0.87      0.88      4433
#
#     accuracy                           0.88      8965
#    macro avg       0.88      0.88      0.88      8965
# weighted avg       0.88      0.88      0.88      8965
#
#
# --------------------------------------------------
#
# Sport: Cycling Road
# Test Accuracy: 0.9289940828402367
# Training MSE: 0.009088987529063623
# Testing MSE: 0.07100591715976332
# Training MAE: 0.009088987529063623
# Testing MAE: 0.07100591715976332
# Confusion Matrix (Test Set):
# [[556  48]
#  [ 36 543]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       604
#            1       0.92      0.94      0.93       579
#
#     accuracy                           0.93      1183
#    macro avg       0.93      0.93      0.93      1183
# weighted avg       0.93      0.93      0.93      1183
#
#
# --------------------------------------------------
#
# Sport: Cycling Track
# Test Accuracy: 0.8270858524788391
# Training MSE: 0.028744326777609682
# Testing MSE: 0.17291414752116083
# Training MAE: 0.028744326777609682
# Testing MAE: 0.17291414752116083
# Confusion Matrix (Test Set):
# [[350  82]
#  [ 61 334]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       432
#            1       0.80      0.85      0.82       395
#
#     accuracy                           0.83       827
#    macro avg       0.83      0.83      0.83       827
# weighted avg       0.83      0.83      0.83       827
#
#
# --------------------------------------------------
#
# Sport: Shooting
# Test Accuracy: 0.8994439295644114
# Training MSE: 0.015063731170336037
# Testing MSE: 0.10055607043558851
# Training MAE: 0.015063731170336037
# Testing MAE: 0.10055607043558851
# Confusion Matrix (Test Set):
# [[959 116]
#  [101 982]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      1075
#            1       0.89      0.91      0.90      1083
#
#     accuracy                           0.90      2158
#    macro avg       0.90      0.90      0.90      2158
# weighted avg       0.90      0.90      0.90      2158
#
#
# --------------------------------------------------
#
# Sport: Weightlifting
# Test Accuracy: 0.85297845373891
# Training MSE: 0.016809387884554394
# Testing MSE: 0.14702154626108999
# Training MAE: 0.016809387884554394
# Testing MAE: 0.14702154626108999
# Confusion Matrix (Test Set):
# [[350  61]
#  [ 55 323]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       411
#            1       0.84      0.85      0.85       378
#
#     accuracy                           0.85       789
#    macro avg       0.85      0.85      0.85       789
# weighted avg       0.85      0.85      0.85       789
#
#
# --------------------------------------------------
#
# Sport: Wrestling
# Test Accuracy: 0.8243346007604563
# Training MSE: 0.01159916333903784
# Testing MSE: 0.17566539923954372
# Training MAE: 0.01159916333903784
# Testing MAE: 0.17566539923954372
# Confusion Matrix (Test Set):
# [[550 121]
#  [110 534]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       671
#            1       0.82      0.83      0.82       644
#
#     accuracy                           0.82      1315
#    macro avg       0.82      0.82      0.82      1315
# weighted avg       0.82      0.82      0.82      1315
#
#
# --------------------------------------------------
#
# Sport: Swimming
# Test Accuracy: 0.8948303428672943
# Training MSE: 0.03295873495313819
# Testing MSE: 0.10516965713270564
# Training MAE: 0.03295873495313819
# Testing MAE: 0.10516965713270564
# Confusion Matrix (Test Set):
# [[2563  268]
#  [ 324 2474]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      2831
#            1       0.90      0.88      0.89      2798
#
#     accuracy                           0.89      5629
#    macro avg       0.90      0.89      0.89      5629
# weighted avg       0.89      0.89      0.89      5629
#
#
# --------------------------------------------------
#
# Sport: Equestrian Jumping
# Test Accuracy: 0.84375
# Training MSE: 0.04833984375
# Testing MSE: 0.15625
# Training MAE: 0.04833984375
# Testing MAE: 0.15625
# Confusion Matrix (Test Set):
# [[223  41]
#  [ 39 209]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85       264
#            1       0.84      0.84      0.84       248
#
#     accuracy                           0.84       512
#    macro avg       0.84      0.84      0.84       512
# weighted avg       0.84      0.84      0.84       512
#
#
# --------------------------------------------------
#
# Sport: Rowing
# Test Accuracy: 0.763873775843308
# Training MSE: 0.01101741022850925
# Testing MSE: 0.23612622415669204
# Training MAE: 0.01101741022850925
# Testing MAE: 0.23612622415669204
# Confusion Matrix (Test Set):
# [[695 224]
#  [210 709]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.77      0.76      0.76       919
#            1       0.76      0.77      0.77       919
#
#     accuracy                           0.76      1838
#    macro avg       0.76      0.76      0.76      1838
# weighted avg       0.76      0.76      0.76      1838
#
#
# --------------------------------------------------
#
# Sport: Sailing
# Test Accuracy: 0.8552437223042836
# Training MSE: 0.0022172949002217295
# Testing MSE: 0.1447562776957164
# Training MAE: 0.0022172949002217295
# Testing MAE: 0.1447562776957164
# Confusion Matrix (Test Set):
# [[553 126]
#  [ 70 605]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85       679
#            1       0.83      0.90      0.86       675
#
#     accuracy                           0.86      1354
#    macro avg       0.86      0.86      0.86      1354
# weighted avg       0.86      0.86      0.86      1354
#
#
# --------------------------------------------------
#
# Sport: Canoe Sprint
# Test Accuracy: 0.8453846153846154
# Training MSE: 0.024624855713736054
# Testing MSE: 0.15461538461538463
# Training MAE: 0.024624855713736054
# Testing MAE: 0.15461538461538463
# Confusion Matrix (Test Set):
# [[562  94]
#  [107 537]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       656
#            1       0.85      0.83      0.84       644
#
#     accuracy                           0.85      1300
#    macro avg       0.85      0.85      0.85      1300
# weighted avg       0.85      0.85      0.85      1300
#
#
# --------------------------------------------------
#
# Sport: Judo
# Test Accuracy: 0.8534635879218473
# Training MSE: 0.012222222222222223
# Testing MSE: 0.14653641207815277
# Training MAE: 0.012222222222222223
# Testing MAE: 0.14653641207815277
# Confusion Matrix (Test Set):
# [[487  83]
#  [ 82 474]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       570
#            1       0.85      0.85      0.85       556
#
#     accuracy                           0.85      1126
#    macro avg       0.85      0.85      0.85      1126
# weighted avg       0.85      0.85      0.85      1126
#
#
# --------------------------------------------------
#
# Sport: Artistic Gymnastics
# Test Accuracy: 0.9331060928845335
# Training MSE: 0.04037068598210482
# Testing MSE: 0.06689390711546656
# Training MAE: 0.04037068598210482
# Testing MAE: 0.06689390711546656
# Confusion Matrix (Test Set):
# [[2208  144]
#  [ 170 2172]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93      2352
#            1       0.94      0.93      0.93      2342
#
#     accuracy                           0.93      4694
#    macro avg       0.93      0.93      0.93      4694
# weighted avg       0.93      0.93      0.93      4694
#
#
# --------------------------------------------------
#
# Sport: Volleyball
# Test Accuracy: 0.7824019024970273
# Training MSE: 0.0017851829812555787
# Testing MSE: 0.21759809750297265
# Training MAE: 0.0017851829812555787
# Testing MAE: 0.21759809750297265
# Confusion Matrix (Test Set):
# [[321 110]
#  [ 73 337]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.81      0.74      0.78       431
#            1       0.75      0.82      0.79       410
#
#     accuracy                           0.78       841
#    macro avg       0.78      0.78      0.78       841
# weighted avg       0.79      0.78      0.78       841
#
#
# --------------------------------------------------
#
# Sport: Diving
# Test Accuracy: 0.8605072463768116
# Training MSE: 0.024909420289855072
# Testing MSE: 0.13949275362318841
# Training MAE: 0.024909420289855072
# Testing MAE: 0.13949275362318841
# Confusion Matrix (Test Set):
# [[233  44]
#  [ 33 242]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       277
#            1       0.85      0.88      0.86       275
#
#     accuracy                           0.86       552
#    macro avg       0.86      0.86      0.86       552
# weighted avg       0.86      0.86      0.86       552
#
#
# --------------------------------------------------
#
# Sport: Football
# Test Accuracy: 0.862413528055342
# Training MSE: 0.0019227071716977505
# Testing MSE: 0.13758647194465795
# Training MAE: 0.0019227071716977505
# Testing MAE: 0.13758647194465795
# Confusion Matrix (Test Set):
# [[563  99]
#  [ 80 559]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       662
#            1       0.85      0.87      0.86       639
#
#     accuracy                           0.86      1301
#    macro avg       0.86      0.86      0.86      1301
# weighted avg       0.86      0.86      0.86      1301
#
#
# --------------------------------------------------
#
# Sport: Canoe Slalom
# Test Accuracy: 0.8769230769230769
# Training MSE: 0.0009652509652509653
# Testing MSE: 0.12307692307692308
# Training MAE: 0.0009652509652509653
# Testing MAE: 0.12307692307692308
# Confusion Matrix (Test Set):
# [[120  16]
#  [ 16 108]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       136
#            1       0.87      0.87      0.87       124
#
#     accuracy                           0.88       260
#    macro avg       0.88      0.88      0.88       260
# weighted avg       0.88      0.88      0.88       260
#
#
# --------------------------------------------------
#
# Sport: Equestrian Dressage
# Test Accuracy: 0.8397212543554007
# Training MSE: 0.06026200873362445
# Testing MSE: 0.1602787456445993
# Training MAE: 0.06026200873362445
# Testing MAE: 0.1602787456445993
# Confusion Matrix (Test Set):
# [[115  22]
#  [ 24 126]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       137
#            1       0.85      0.84      0.85       150
#
#     accuracy                           0.84       287
#    macro avg       0.84      0.84      0.84       287
# weighted avg       0.84      0.84      0.84       287
#
#
# --------------------------------------------------
#
# Sport: Equestrian Eventing
# Test Accuracy: 0.8403547671840355
# Training MSE: 0.04719600222098834
# Testing MSE: 0.15964523281596452
# Training MAE: 0.04719600222098834
# Testing MAE: 0.15964523281596452
# Confusion Matrix (Test Set):
# [[187  42]
#  [ 30 192]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       229
#            1       0.82      0.86      0.84       222
#
#     accuracy                           0.84       451
#    macro avg       0.84      0.84      0.84       451
# weighted avg       0.84      0.84      0.84       451
#
#
# --------------------------------------------------
#
# Sport: Fencing
# Test Accuracy: 0.8247890979883192
# Training MSE: 0.04658334685927609
# Testing MSE: 0.1752109020116807
# Training MAE: 0.04658334685927609
# Testing MAE: 0.1752109020116807
# Confusion Matrix (Test Set):
# [[653 128]
#  [142 618]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       781
#            1       0.83      0.81      0.82       760
#
#     accuracy                           0.82      1541
#    macro avg       0.82      0.82      0.82      1541
# weighted avg       0.82      0.82      0.82      1541
#
#
# --------------------------------------------------
#
# Sport: Handball
# Test Accuracy: 0.7993827160493827
# Training MSE: 0.00051440329218107
# Testing MSE: 0.2006172839506173
# Training MAE: 0.00051440329218107
# Testing MAE: 0.2006172839506173
# Confusion Matrix (Test Set):
# [[367 115]
#  [ 80 410]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79       482
#            1       0.78      0.84      0.81       490
#
#     accuracy                           0.80       972
#    macro avg       0.80      0.80      0.80       972
# weighted avg       0.80      0.80      0.80       972
#
#
# --------------------------------------------------
#
# Sport: Basketball
# Test Accuracy: 0.8464373464373465
# Training MSE: 0.00030731407498463427
# Testing MSE: 0.15356265356265356
# Training MAE: 0.00030731407498463427
# Testing MAE: 0.15356265356265356
# Confusion Matrix (Test Set):
# [[358  74]
#  [ 51 331]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       432
#            1       0.82      0.87      0.84       382
#
#     accuracy                           0.85       814
#    macro avg       0.85      0.85      0.85       814
# weighted avg       0.85      0.85      0.85       814
#
#
# --------------------------------------------------
#
# Sport: Water Polo
# Test Accuracy: 0.8078740157480315
# Training MSE: 0.0035474970437524636
# Testing MSE: 0.1921259842519685
# Training MAE: 0.0035474970437524636
# Testing MAE: 0.1921259842519685
# Confusion Matrix (Test Set):
# [[262  63]
#  [ 59 251]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81       325
#            1       0.80      0.81      0.80       310
#
#     accuracy                           0.81       635
#    macro avg       0.81      0.81      0.81       635
# weighted avg       0.81      0.81      0.81       635
#
#
# --------------------------------------------------
#
# Sport: Hockey
# Test Accuracy: 0.7956273764258555
# Training MSE: 0.003564638783269962
# Testing MSE: 0.20437262357414449
# Training MAE: 0.003564638783269962
# Testing MAE: 0.20437262357414449
# Confusion Matrix (Test Set):
# [[404 108]
#  [107 433]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79       512
#            1       0.80      0.80      0.80       540
#
#     accuracy                           0.80      1052
#    macro avg       0.80      0.80      0.80      1052
# weighted avg       0.80      0.80      0.80      1052
#
#
# --------------------------------------------------
#
# Sport: Modern Pentathlon
# Test Accuracy: 0.907185628742515
# Training MSE: 0.017991004497751123
# Testing MSE: 0.09281437125748503
# Training MAE: 0.017991004497751123
# Testing MAE: 0.09281437125748503
# Confusion Matrix (Test Set):
# [[157  19]
#  [ 12 146]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       176
#            1       0.88      0.92      0.90       158
#
#     accuracy                           0.91       334
#    macro avg       0.91      0.91      0.91       334
# weighted avg       0.91      0.91      0.91       334
#
#
# --------------------------------------------------
#
# Sport: Archery
# Test Accuracy: 0.8739130434782608
# Training MSE: 0.027939042089985485
# Testing MSE: 0.12608695652173912
# Training MAE: 0.027939042089985485
# Testing MAE: 0.12608695652173912
# Confusion Matrix (Test Set):
# [[312  39]
#  [ 48 291]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       351
#            1       0.88      0.86      0.87       339
#
#     accuracy                           0.87       690
#    macro avg       0.87      0.87      0.87       690
# weighted avg       0.87      0.87      0.87       690
#
#
# --------------------------------------------------
#
# Sport: Speed Skating
# Test Accuracy: 0.8568493150684932
# Training MSE: 0.03752570253598355
# Testing MSE: 0.14315068493150684
# Training MAE: 0.03752570253598355
# Testing MAE: 0.14315068493150684
# Confusion Matrix (Test Set):
# [[658  97]
#  [112 593]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       755
#            1       0.86      0.84      0.85       705
#
#     accuracy                           0.86      1460
#    macro avg       0.86      0.86      0.86      1460
# weighted avg       0.86      0.86      0.86      1460
#
#
# --------------------------------------------------
#
# Sport: Alpine Skiing
# Test Accuracy: 0.9221987315010571
# Training MSE: 0.02167706460822671
# Testing MSE: 0.07780126849894292
# Training MAE: 0.02167706460822671
# Testing MAE: 0.07780126849894292
# Confusion Matrix (Test Set):
# [[1092   96]
#  [  88 1089]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      1188
#            1       0.92      0.93      0.92      1177
#
#     accuracy                           0.92      2365
#    macro avg       0.92      0.92      0.92      2365
# weighted avg       0.92      0.92      0.92      2365
#
#
# --------------------------------------------------
#
# Sport: Cross Country Skiing
# Test Accuracy: 0.9230769230769231
# Training MSE: 0.03279754715228096
# Testing MSE: 0.07692307692307693
# Training MAE: 0.03279754715228096
# Testing MAE: 0.07692307692307693
# Confusion Matrix (Test Set):
# [[1278   98]
#  [ 109 1206]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.93      1376
#            1       0.92      0.92      0.92      1315
#
#     accuracy                           0.92      2691
#    macro avg       0.92      0.92      0.92      2691
# weighted avg       0.92      0.92      0.92      2691
#
#
# --------------------------------------------------
#
# Sport: Biathlon
# Test Accuracy: 0.9132791327913279
# Training MSE: 0.039436237972625014
# Testing MSE: 0.08672086720867209
# Training MAE: 0.039436237972625014
# Testing MAE: 0.08672086720867209
# Confusion Matrix (Test Set):
# [[855  76]
#  [ 84 830]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       931
#            1       0.92      0.91      0.91       914
#
#     accuracy                           0.91      1845
#    macro avg       0.91      0.91      0.91      1845
# weighted avg       0.91      0.91      0.91      1845
#
#
# --------------------------------------------------
#
# Sport: Figure Skating
# Test Accuracy: 0.8413654618473896
# Training MSE: 0.019095477386934675
# Testing MSE: 0.15863453815261044
# Training MAE: 0.019095477386934675
# Testing MAE: 0.15863453815261044
# Confusion Matrix (Test Set):
# [[215  34]
#  [ 45 204]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84       249
#            1       0.86      0.82      0.84       249
#
#     accuracy                           0.84       498
#    macro avg       0.84      0.84      0.84       498
# weighted avg       0.84      0.84      0.84       498
#
#
# --------------------------------------------------
#
# Sport: Luge
# Test Accuracy: 0.8778947368421053
# Training MSE: 0.008961518186610437
# Testing MSE: 0.12210526315789473
# Training MAE: 0.008961518186610437
# Testing MAE: 0.12210526315789473
# Confusion Matrix (Test Set):
# [[201  36]
#  [ 22 216]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87       237
#            1       0.86      0.91      0.88       238
#
#     accuracy                           0.88       475
#    macro avg       0.88      0.88      0.88       475
# weighted avg       0.88      0.88      0.88       475
#
#
# --------------------------------------------------
#
# Sport: Nordic Combined
# Test Accuracy: 0.8604651162790697
# Training MSE: 0.04524886877828054
# Testing MSE: 0.13953488372093023
# Training MAE: 0.04524886877828054
# Testing MAE: 0.13953488372093023
# Confusion Matrix (Test Set):
# [[166  26]
#  [ 28 167]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       192
#            1       0.87      0.86      0.86       195
#
#     accuracy                           0.86       387
#    macro avg       0.86      0.86      0.86       387
# weighted avg       0.86      0.86      0.86       387
#
#
# --------------------------------------------------
#
# Sport: Ski Jumping
# Test Accuracy: 0.8885672937771346
# Training MSE: 0.035830618892508145
# Testing MSE: 0.11143270622286541
# Training MAE: 0.035830618892508145
# Testing MAE: 0.11143270622286541
# Confusion Matrix (Test Set):
# [[326  38]
#  [ 39 288]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       364
#            1       0.88      0.88      0.88       327
#
#     accuracy                           0.89       691
#    macro avg       0.89      0.89      0.89       691
# weighted avg       0.89      0.89      0.89       691
#
#
# --------------------------------------------------
#
# Sport: Ice Hockey
# Test Accuracy: 0.8238683127572016
# Training MSE: 0.006174109899156205
# Testing MSE: 0.17613168724279835
# Training MAE: 0.006174109899156205
# Testing MAE: 0.17613168724279835
# Confusion Matrix (Test Set):
# [[488 110]
#  [104 513]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       598
#            1       0.82      0.83      0.83       617
#
#     accuracy                           0.82      1215
#    macro avg       0.82      0.82      0.82      1215
# weighted avg       0.82      0.82      0.82      1215
#
#
# --------------------------------------------------
#
# Sport: Bobsleigh
# Test Accuracy: 0.8699080157687253
# Training MSE: 0.020374630299046993
# Testing MSE: 0.13009198423127463
# Training MAE: 0.020374630299046993
# Testing MAE: 0.13009198423127463
# Confusion Matrix (Test Set):
# [[334  48]
#  [ 51 328]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87       382
#            1       0.87      0.87      0.87       379
#
#     accuracy                           0.87       761
#    macro avg       0.87      0.87      0.87       761
# weighted avg       0.87      0.87      0.87       761
#
#
# --------------------------------------------------
#
# Sport: Baseball
# Test Accuracy: 0.8258928571428571
# Training MSE: 0.0011185682326621924
# Testing MSE: 0.17410714285714285
# Training MAE: 0.0011185682326621924
# Testing MAE: 0.17410714285714285
# Confusion Matrix (Test Set):
# [[ 79  25]
#  [ 14 106]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80       104
#            1       0.81      0.88      0.84       120
#
#     accuracy                           0.83       224
#    macro avg       0.83      0.82      0.82       224
# weighted avg       0.83      0.83      0.82       224
#
#
# --------------------------------------------------
#
# Sport: Tennis
# Test Accuracy: 0.8991935483870968
# Training MSE: 0.01881720430107527
# Testing MSE: 0.10080645161290322
# Training MAE: 0.01881720430107527
# Testing MAE: 0.10080645161290322
# Confusion Matrix (Test Set):
# [[339  42]
#  [ 33 330]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       381
#            1       0.89      0.91      0.90       363
#
#     accuracy                           0.90       744
#    macro avg       0.90      0.90      0.90       744
# weighted avg       0.90      0.90      0.90       744
#
#
# --------------------------------------------------
#
# Sport: Artistic Swimming
# Test Accuracy: 0.8517110266159695
# Training MSE: 0.017159199237368923
# Testing MSE: 0.1482889733840304
# Training MAE: 0.017159199237368923
# Testing MAE: 0.1482889733840304
# Confusion Matrix (Test Set):
# [[112  21]
#  [ 18 112]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       133
#            1       0.84      0.86      0.85       130
#
#     accuracy                           0.85       263
#    macro avg       0.85      0.85      0.85       263
# weighted avg       0.85      0.85      0.85       263
#
#
# --------------------------------------------------
#
# Sport: Rhythmic Gymnastics
# Test Accuracy: 0.8536585365853658
# Training MSE: 0.007326007326007326
# Testing MSE: 0.14634146341463414
# Training MAE: 0.007326007326007326
# Testing MAE: 0.14634146341463414
# Confusion Matrix (Test Set):
# [[85 18]
#  [12 90]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85       103
#            1       0.83      0.88      0.86       102
#
#     accuracy                           0.85       205
#    macro avg       0.85      0.85      0.85       205
# weighted avg       0.85      0.85      0.85       205
#
#
# --------------------------------------------------
#
# Sport: Table Tennis
# Test Accuracy: 0.9296407185628742
# Training MSE: 0.015730337078651686
# Testing MSE: 0.07035928143712575
# Training MAE: 0.015730337078651686
# Testing MAE: 0.07035928143712575
# Confusion Matrix (Test Set):
# [[333  27]
#  [ 20 288]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       360
#            1       0.91      0.94      0.92       308
#
#     accuracy                           0.93       668
#    macro avg       0.93      0.93      0.93       668
# weighted avg       0.93      0.93      0.93       668
#
#
# --------------------------------------------------
#
# Sport: Badminton
# Test Accuracy: 0.889795918367347
# Training MSE: 0.010725229826353423
# Testing MSE: 0.11020408163265306
# Training MAE: 0.010725229826353423
# Testing MAE: 0.11020408163265306
# Confusion Matrix (Test Set):
# [[219  33]
#  [ 21 217]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       252
#            1       0.87      0.91      0.89       238
#
#     accuracy                           0.89       490
#    macro avg       0.89      0.89      0.89       490
# weighted avg       0.89      0.89      0.89       490
#
#
# --------------------------------------------------
#
# Sport: Taekwondo
# Test Accuracy: 0.8260869565217391
# Training MSE: 0.0
# Testing MSE: 0.17391304347826086
# Training MAE: 0.0
# Testing MAE: 0.17391304347826086
# Confusion Matrix (Test Set):
# [[74 16]
#  [16 78]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82        90
#            1       0.83      0.83      0.83        94
#
#     accuracy                           0.83       184
#    macro avg       0.83      0.83      0.83       184
# weighted avg       0.83      0.83      0.83       184
#
#
# --------------------------------------------------
#
# Sport: Curling
# Test Accuracy: 0.7741935483870968
# Training MSE: 0.008108108108108109
# Testing MSE: 0.22580645161290322
# Training MAE: 0.008108108108108109
# Testing MAE: 0.22580645161290322
# Confusion Matrix (Test Set):
# [[63 28]
#  [14 81]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.82      0.69      0.75        91
#            1       0.74      0.85      0.79        95
#
#     accuracy                           0.77       186
#    macro avg       0.78      0.77      0.77       186
# weighted avg       0.78      0.77      0.77       186
#
#
# --------------------------------------------------
#
# Sport: Short Track Speed Skating
# Test Accuracy: 0.854493580599144
# Training MSE: 0.062076346771316446
# Testing MSE: 0.14550641940085593
# Training MAE: 0.062076346771316446
# Testing MAE: 0.14550641940085593
# Confusion Matrix (Test Set):
# [[329  55]
#  [ 47 270]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       384
#            1       0.83      0.85      0.84       317
#
#     accuracy                           0.85       701
#    macro avg       0.85      0.85      0.85       701
# weighted avg       0.85      0.85      0.85       701
#
#
# --------------------------------------------------
#
# Sport: Freestyle Skiing
# Test Accuracy: 0.8491379310344828
# Training MSE: 0.003236245954692557
# Testing MSE: 0.15086206896551724
# Training MAE: 0.003236245954692557
# Testing MAE: 0.15086206896551724
# Confusion Matrix (Test Set):
# [[205  40]
#  [ 30 189]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       245
#            1       0.83      0.86      0.84       219
#
#     accuracy                           0.85       464
#    macro avg       0.85      0.85      0.85       464
# weighted avg       0.85      0.85      0.85       464
#
#
# --------------------------------------------------
#
# Sport: Cycling Mountain Bike
# Test Accuracy: 0.9653179190751445
# Training MSE: 0.001451378809869376
# Testing MSE: 0.03468208092485549
# Training MAE: 0.001451378809869376
# Testing MAE: 0.03468208092485549
# Confusion Matrix (Test Set):
# [[83  4]
#  [ 2 84]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        87
#            1       0.95      0.98      0.97        86
#
#     accuracy                           0.97       173
#    macro avg       0.97      0.97      0.97       173
# weighted avg       0.97      0.97      0.97       173
#
#
# --------------------------------------------------
#
# Sport: Softball
# Test Accuracy: 0.9537037037037037
# Training MSE: 0.0
# Testing MSE: 0.046296296296296294
# Training MAE: 0.0
# Testing MAE: 0.046296296296296294
# Confusion Matrix (Test Set):
# [[50  2]
#  [ 3 53]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        52
#            1       0.96      0.95      0.95        56
#
#     accuracy                           0.95       108
#    macro avg       0.95      0.95      0.95       108
# weighted avg       0.95      0.95      0.95       108
#
#
# --------------------------------------------------
#
# Sport: Beach Volleyball
# Test Accuracy: 0.8894472361809045
# Training MSE: 0.0
# Testing MSE: 0.11055276381909548
# Training MAE: 0.0
# Testing MAE: 0.11055276381909548
# Confusion Matrix (Test Set):
# [[88 12]
#  [10 89]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       100
#            1       0.88      0.90      0.89        99
#
#     accuracy                           0.89       199
#    macro avg       0.89      0.89      0.89       199
# weighted avg       0.89      0.89      0.89       199
#
#
# --------------------------------------------------
#
# Sport: Snowboarding
# Test Accuracy: 0.854389721627409
# Training MSE: 0.011260053619302948
# Testing MSE: 0.145610278372591
# Training MAE: 0.011260053619302948
# Testing MAE: 0.145610278372591
# Confusion Matrix (Test Set):
# [[191  34]
#  [ 34 208]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85       225
#            1       0.86      0.86      0.86       242
#
#     accuracy                           0.85       467
#    macro avg       0.85      0.85      0.85       467
# weighted avg       0.85      0.85      0.85       467
#
#
# --------------------------------------------------
#
# Sport: Trampolining
# Test Accuracy: 0.9
# Training MSE: 0.0
# Testing MSE: 0.1
# Training MAE: 0.0
# Testing MAE: 0.1
# Confusion Matrix (Test Set):
# [[21  3]
#  [ 2 24]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89        24
#            1       0.89      0.92      0.91        26
#
#     accuracy                           0.90        50
#    macro avg       0.90      0.90      0.90        50
# weighted avg       0.90      0.90      0.90        50
#
#
# --------------------------------------------------
#
# Sport: Triathlon
# Test Accuracy: 0.9386792452830188
# Training MSE: 0.0035545023696682463
# Testing MSE: 0.06132075471698113
# Training MAE: 0.0035545023696682463
# Testing MAE: 0.06132075471698113
# Confusion Matrix (Test Set):
# [[106  10]
#  [  3  93]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94       116
#            1       0.90      0.97      0.93        96
#
#     accuracy                           0.94       212
#    macro avg       0.94      0.94      0.94       212
# weighted avg       0.94      0.94      0.94       212
#
#
# --------------------------------------------------
#
# Sport: Cycling BMX Racing
# Test Accuracy: 0.9272727272727272
# Training MSE: 0.0
# Testing MSE: 0.07272727272727272
# Training MAE: 0.0
# Testing MAE: 0.07272727272727272
# Confusion Matrix (Test Set):
# [[25  4]
#  [ 0 26]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       1.00      0.86      0.93        29
#            1       0.87      1.00      0.93        26
#
#     accuracy                           0.93        55
#    macro avg       0.93      0.93      0.93        55
# weighted avg       0.94      0.93      0.93        55
#
#
# --------------------------------------------------
#
# Sport: Marathon Swimming
# Test Accuracy: 0.8793103448275862
# Training MSE: 0.0
# Testing MSE: 0.1206896551724138
# Training MAE: 0.0
# Testing MAE: 0.1206896551724138
# Confusion Matrix (Test Set):
# [[21  4]
#  [ 3 30]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        25
#            1       0.88      0.91      0.90        33
#
#     accuracy                           0.88        58
#    macro avg       0.88      0.87      0.88        58
# weighted avg       0.88      0.88      0.88        58
#
#
# --------------------------------------------------
#
# Sport: Skeleton
# Test Accuracy: 0.8771929824561403
# Training MSE: 0.0
# Testing MSE: 0.12280701754385964
# Training MAE: 0.0
# Testing MAE: 0.12280701754385964
# Confusion Matrix (Test Set):
# [[19  4]
#  [ 3 31]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        23
#            1       0.89      0.91      0.90        34
#
#     accuracy                           0.88        57
#    macro avg       0.87      0.87      0.87        57
# weighted avg       0.88      0.88      0.88        57
#
#
# --------------------------------------------------
#
# Sport: Golf
# Test Accuracy: 0.9814814814814815
# Training MSE: 0.0
# Testing MSE: 0.018518518518518517
# Training MAE: 0.0
# Testing MAE: 0.018518518518518517
# Confusion Matrix (Test Set):
# [[29  1]
#  [ 0 24]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.98        30
#            1       0.96      1.00      0.98        24
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54
#
#
# --------------------------------------------------
#
# Sport: Rugby Sevens
# Test Accuracy: 0.9212598425196851
# Training MSE: 0.0
# Testing MSE: 0.07874015748031496
# Training MAE: 0.0
# Testing MAE: 0.07874015748031496
# Confusion Matrix (Test Set):
# [[65  7]
#  [ 3 52]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        72
#            1       0.88      0.95      0.91        55
#
#     accuracy                           0.92       127
#    macro avg       0.92      0.92      0.92       127
# weighted avg       0.92      0.92      0.92       127
#
#
# --------------------------------------------------
#
# Sport: 3x3 Basketball
# Test Accuracy: 0.0
# Training MSE: 0.0
# Testing MSE: 1.0
# Training MAE: 0.0
# Testing MAE: 1.0
# Confusion Matrix (Test Set):
# [[0 1]
#  [0 0]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       1.0
#            1       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.00      0.00      0.00       1.0
# weighted avg       0.00      0.00      0.00       1.0
#
#
# --------------------------------------------------
#
# Sport: Skateboarding
# Test Accuracy: 0.8
# Training MSE: 0.0
# Testing MSE: 0.2
# Training MAE: 0.0
# Testing MAE: 0.2
# Confusion Matrix (Test Set):
# [[2 1]
#  [0 2]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       1.00      0.67      0.80         3
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.80         5
#    macro avg       0.83      0.83      0.80         5
# weighted avg       0.87      0.80      0.80         5
#
#
# --------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Sport: Surfing
# Test Accuracy: 0.6666666666666666
# Training MSE: 0.0
# Testing MSE: 0.3333333333333333
# Training MAE: 0.0
# Testing MAE: 0.3333333333333333
# Confusion Matrix (Test Set):
# [[0 0]
#  [1 2]]
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.33      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# --------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Support Vector Machine
from sklearn.svm import SVC
from sklearn.metrics import (
    mean_squared_error, confusion_matrix,
    accuracy_score, classification_report
)
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import numpy as np
import pandas as pd

# Group the data by sport and perform separate analysis for each sport
for sport in df_scaled['Sport'].unique():
    df_sport = df_scaled[df_scaled['Sport'] == sport]

    if df_sport.shape[0] > 0:  # Check if the sport group has enough data
        # Select relevant features (e.g., Scaled_BMI, Scaled_Age, Country) and target variable
        X = df_sport[['Scaled_BMI', 'Scaled_Age', 'Country']]

        # One hot encode the country column
        X = pd.get_dummies(X, columns=['Country'], prefix=['Country'])
        y = df_sport['Medal_Indicator']

        # Check if there are at least two classes in the target variable
        if len(np.unique(y)) > 1:
            minority_class_size = np.min(np.bincount(y))
            k_neighbors = min(5, minority_class_size - 1) if minority_class_size > 1 else 1
            smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
            X_resampled, y_resampled = smote.fit_resample(X, y)

            # Split data into training and testing sets
            X_train, X_test, y_train, y_test = train_test_split(
                X_resampled, y_resampled, test_size=0.2, random_state=42
            )

            # Train an SVM model
            model = SVC(random_state=42)
            model.fit(X_train, y_train)

            # Make predictions on the training and test sets
            y_train_pred = model.predict(X_train)
            y_test_pred = model.predict(X_test)

            # Calculate training and testing MSE
            train_mse = mean_squared_error(y_train, y_train_pred)
            test_mse = mean_squared_error(y_test, y_test_pred)


            # Calculate accuracy, confusion matrix, and classification report for the test set
            accuracy = accuracy_score(y_test, y_test_pred)
            conf_matrix = confusion_matrix(y_test, y_test_pred)
            report = classification_report(y_test, y_test_pred, zero_division=1)

            # Output the results
            print(f"Sport: {sport}")
            print(f"Training MSE: {train_mse:.4f}")
            print(f"Testing MSE: {test_mse:.4f}")
            print(f"Testing Accuracy: {accuracy:.4f}")
            print("Confusion Matrix:\n", conf_matrix)
            print("Classification Report:\n", report)
            print("\n" + "-"*50 + "\n")
# Out:
# Sport: Boxing
# Training MSE: 0.1820
# Testing MSE: 0.1956
# Testing Accuracy: 0.8044
# Confusion Matrix:
#  [[440 158]
#  [ 73 510]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.74      0.79       598
#            1       0.76      0.87      0.82       583
#
#     accuracy                           0.80      1181
#    macro avg       0.81      0.81      0.80      1181
# weighted avg       0.81      0.80      0.80      1181
#
#
# --------------------------------------------------
#
# Sport: Athletics
# Training MSE: 0.2214
# Testing MSE: 0.2259
# Testing Accuracy: 0.7741
# Confusion Matrix:
#  [[3151 1381]
#  [ 644 3789]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76      4532
#            1       0.73      0.85      0.79      4433
#
#     accuracy                           0.77      8965
#    macro avg       0.78      0.78      0.77      8965
# weighted avg       0.78      0.77      0.77      8965
#
#
# --------------------------------------------------
#
# Sport: Cycling Road
# Training MSE: 0.1289
# Testing MSE: 0.1547
# Testing Accuracy: 0.8453
# Confusion Matrix:
#  [[456 148]
#  [ 35 544]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83       604
#            1       0.79      0.94      0.86       579
#
#     accuracy                           0.85      1183
#    macro avg       0.86      0.85      0.84      1183
# weighted avg       0.86      0.85      0.84      1183
#
#
# --------------------------------------------------
#
# Sport: Cycling Track
# Training MSE: 0.2124
# Testing MSE: 0.2382
# Testing Accuracy: 0.7618
# Confusion Matrix:
#  [[295 137]
#  [ 60 335]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.68      0.75       432
#            1       0.71      0.85      0.77       395
#
#     accuracy                           0.76       827
#    macro avg       0.77      0.77      0.76       827
# weighted avg       0.77      0.76      0.76       827
#
#
# --------------------------------------------------
#
# Sport: Shooting
# Training MSE: 0.1844
# Testing MSE: 0.1900
# Testing Accuracy: 0.8100
# Confusion Matrix:
#  [[785 290]
#  [120 963]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79      1075
#            1       0.77      0.89      0.82      1083
#
#     accuracy                           0.81      2158
#    macro avg       0.82      0.81      0.81      2158
# weighted avg       0.82      0.81      0.81      2158
#
#
# --------------------------------------------------
#
# Sport: Weightlifting
# Training MSE: 0.1859
# Testing MSE: 0.2015
# Testing Accuracy: 0.7985
# Confusion Matrix:
#  [[308 103]
#  [ 56 322]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.75      0.79       411
#            1       0.76      0.85      0.80       378
#
#     accuracy                           0.80       789
#    macro avg       0.80      0.80      0.80       789
# weighted avg       0.80      0.80      0.80       789
#
#
# --------------------------------------------------
#
# Sport: Wrestling
# Training MSE: 0.2362
# Testing MSE: 0.2586
# Testing Accuracy: 0.7414
# Confusion Matrix:
#  [[441 230]
#  [110 534]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.66      0.72       671
#            1       0.70      0.83      0.76       644
#
#     accuracy                           0.74      1315
#    macro avg       0.75      0.74      0.74      1315
# weighted avg       0.75      0.74      0.74      1315
#
#
# --------------------------------------------------
#
# Sport: Swimming
# Training MSE: 0.2050
# Testing MSE: 0.2048
# Testing Accuracy: 0.7952
# Confusion Matrix:
#  [[2159  672]
#  [ 481 2317]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.76      0.79      2831
#            1       0.78      0.83      0.80      2798
#
#     accuracy                           0.80      5629
#    macro avg       0.80      0.80      0.80      5629
# weighted avg       0.80      0.80      0.79      5629
#
#
# --------------------------------------------------
#
# Sport: Equestrian Jumping
# Training MSE: 0.1792
# Testing MSE: 0.2109
# Testing Accuracy: 0.7891
# Confusion Matrix:
#  [[194  70]
#  [ 38 210]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.73      0.78       264
#            1       0.75      0.85      0.80       248
#
#     accuracy                           0.79       512
#    macro avg       0.79      0.79      0.79       512
# weighted avg       0.79      0.79      0.79       512
#
#
# --------------------------------------------------
#
# Sport: Rowing
# Training MSE: 0.2933
# Testing MSE: 0.2992
# Testing Accuracy: 0.7008
# Confusion Matrix:
#  [[558 361]
#  [189 730]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.61      0.67       919
#            1       0.67      0.79      0.73       919
#
#     accuracy                           0.70      1838
#    macro avg       0.71      0.70      0.70      1838
# weighted avg       0.71      0.70      0.70      1838
#
#
# --------------------------------------------------
#
# Sport: Sailing
# Training MSE: 0.2121
# Testing MSE: 0.2459
# Testing Accuracy: 0.7541
# Confusion Matrix:
#  [[444 235]
#  [ 98 577]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.65      0.73       679
#            1       0.71      0.85      0.78       675
#
#     accuracy                           0.75      1354
#    macro avg       0.76      0.75      0.75      1354
# weighted avg       0.77      0.75      0.75      1354
#
#
# --------------------------------------------------
#
# Sport: Canoe Sprint
# Training MSE: 0.2274
# Testing MSE: 0.2238
# Testing Accuracy: 0.7762
# Confusion Matrix:
#  [[445 211]
#  [ 80 564]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75       656
#            1       0.73      0.88      0.79       644
#
#     accuracy                           0.78      1300
#    macro avg       0.79      0.78      0.77      1300
# weighted avg       0.79      0.78      0.77      1300
#
#
# --------------------------------------------------
#
# Sport: Judo
# Training MSE: 0.1771
# Testing MSE: 0.2016
# Testing Accuracy: 0.7984
# Confusion Matrix:
#  [[418 152]
#  [ 75 481]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.73      0.79       570
#            1       0.76      0.87      0.81       556
#
#     accuracy                           0.80      1126
#    macro avg       0.80      0.80      0.80      1126
# weighted avg       0.80      0.80      0.80      1126
#
#
# --------------------------------------------------
#
# Sport: Artistic Gymnastics
# Training MSE: 0.1935
# Testing MSE: 0.1975
# Testing Accuracy: 0.8025
# Confusion Matrix:
#  [[1693  659]
#  [ 268 2074]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.72      0.79      2352
#            1       0.76      0.89      0.82      2342
#
#     accuracy                           0.80      4694
#    macro avg       0.81      0.80      0.80      4694
# weighted avg       0.81      0.80      0.80      4694
#
#
# --------------------------------------------------
#
# Sport: Volleyball
# Training MSE: 0.2339
# Testing MSE: 0.2449
# Testing Accuracy: 0.7551
# Confusion Matrix:
#  [[280 151]
#  [ 55 355]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.65      0.73       431
#            1       0.70      0.87      0.78       410
#
#     accuracy                           0.76       841
#    macro avg       0.77      0.76      0.75       841
# weighted avg       0.77      0.76      0.75       841
#
#
# --------------------------------------------------
#
# Sport: Diving
# Training MSE: 0.1938
# Testing MSE: 0.2301
# Testing Accuracy: 0.7699
# Confusion Matrix:
#  [[194  83]
#  [ 44 231]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.70      0.75       277
#            1       0.74      0.84      0.78       275
#
#     accuracy                           0.77       552
#    macro avg       0.78      0.77      0.77       552
# weighted avg       0.78      0.77      0.77       552
#
#
# --------------------------------------------------
#
# Sport: Football
# Training MSE: 0.1577
# Testing MSE: 0.1637
# Testing Accuracy: 0.8363
# Confusion Matrix:
#  [[535 127]
#  [ 86 553]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83       662
#            1       0.81      0.87      0.84       639
#
#     accuracy                           0.84      1301
#    macro avg       0.84      0.84      0.84      1301
# weighted avg       0.84      0.84      0.84      1301
#
#
# --------------------------------------------------
#
# Sport: Canoe Slalom
# Training MSE: 0.1535
# Testing MSE: 0.1731
# Testing Accuracy: 0.8269
# Confusion Matrix:
#  [[106  30]
#  [ 15 109]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82       136
#            1       0.78      0.88      0.83       124
#
#     accuracy                           0.83       260
#    macro avg       0.83      0.83      0.83       260
# weighted avg       0.83      0.83      0.83       260
#
#
# --------------------------------------------------
#
# Sport: Equestrian Dressage
# Training MSE: 0.1738
# Testing MSE: 0.1951
# Testing Accuracy: 0.8049
# Confusion Matrix:
#  [[101  36]
#  [ 20 130]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78       137
#            1       0.78      0.87      0.82       150
#
#     accuracy                           0.80       287
#    macro avg       0.81      0.80      0.80       287
# weighted avg       0.81      0.80      0.80       287
#
#
# --------------------------------------------------
#
# Sport: Equestrian Eventing
# Training MSE: 0.1738
# Testing MSE: 0.1796
# Testing Accuracy: 0.8204
# Confusion Matrix:
#  [[161  68]
#  [ 13 209]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.70      0.80       229
#            1       0.75      0.94      0.84       222
#
#     accuracy                           0.82       451
#    macro avg       0.84      0.82      0.82       451
# weighted avg       0.84      0.82      0.82       451
#
#
# --------------------------------------------------
#
# Sport: Fencing
# Training MSE: 0.2389
# Testing MSE: 0.2291
# Testing Accuracy: 0.7709
# Confusion Matrix:
#  [[535 246]
#  [107 653]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.69      0.75       781
#            1       0.73      0.86      0.79       760
#
#     accuracy                           0.77      1541
#    macro avg       0.78      0.77      0.77      1541
# weighted avg       0.78      0.77      0.77      1541
#
#
# --------------------------------------------------
#
# Sport: Handball
# Training MSE: 0.2070
# Testing MSE: 0.2212
# Testing Accuracy: 0.7788
# Confusion Matrix:
#  [[318 164]
#  [ 51 439]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75       482
#            1       0.73      0.90      0.80       490
#
#     accuracy                           0.78       972
#    macro avg       0.79      0.78      0.78       972
# weighted avg       0.79      0.78      0.78       972
#
#
# --------------------------------------------------
#
# Sport: Basketball
# Training MSE: 0.1567
# Testing MSE: 0.1671
# Testing Accuracy: 0.8329
# Confusion Matrix:
#  [[345  87]
#  [ 49 333]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       432
#            1       0.79      0.87      0.83       382
#
#     accuracy                           0.83       814
#    macro avg       0.83      0.84      0.83       814
# weighted avg       0.84      0.83      0.83       814
#
#
# --------------------------------------------------
#
# Sport: Water Polo
# Training MSE: 0.2089
# Testing MSE: 0.1748
# Testing Accuracy: 0.8252
# Confusion Matrix:
#  [[251  74]
#  [ 37 273]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82       325
#            1       0.79      0.88      0.83       310
#
#     accuracy                           0.83       635
#    macro avg       0.83      0.83      0.82       635
# weighted avg       0.83      0.83      0.82       635
#
#
# --------------------------------------------------
#
# Sport: Hockey
# Training MSE: 0.2414
# Testing MSE: 0.2234
# Testing Accuracy: 0.7766
# Confusion Matrix:
#  [[362 150]
#  [ 85 455]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.71      0.75       512
#            1       0.75      0.84      0.79       540
#
#     accuracy                           0.78      1052
#    macro avg       0.78      0.77      0.77      1052
# weighted avg       0.78      0.78      0.78      1052
#
#
# --------------------------------------------------
#
# Sport: Modern Pentathlon
# Training MSE: 0.1252
# Testing MSE: 0.1347
# Testing Accuracy: 0.8653
# Confusion Matrix:
#  [[144  32]
#  [ 13 145]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.82      0.86       176
#            1       0.82      0.92      0.87       158
#
#     accuracy                           0.87       334
#    macro avg       0.87      0.87      0.87       334
# weighted avg       0.87      0.87      0.87       334
#
#
# --------------------------------------------------
#
# Sport: Archery
# Training MSE: 0.1295
# Testing MSE: 0.1623
# Testing Accuracy: 0.8377
# Confusion Matrix:
#  [[273  78]
#  [ 34 305]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       351
#            1       0.80      0.90      0.84       339
#
#     accuracy                           0.84       690
#    macro avg       0.84      0.84      0.84       690
# weighted avg       0.84      0.84      0.84       690
#
#
# --------------------------------------------------
#
# Sport: Speed Skating
# Training MSE: 0.2978
# Testing MSE: 0.3096
# Testing Accuracy: 0.6904
# Confusion Matrix:
#  [[436 319]
#  [133 572]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.58      0.66       755
#            1       0.64      0.81      0.72       705
#
#     accuracy                           0.69      1460
#    macro avg       0.70      0.69      0.69      1460
# weighted avg       0.71      0.69      0.69      1460
#
#
# --------------------------------------------------
#
# Sport: Alpine Skiing
# Training MSE: 0.1985
# Testing MSE: 0.2085
# Testing Accuracy: 0.7915
# Confusion Matrix:
#  [[ 753  435]
#  [  58 1119]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75      1188
#            1       0.72      0.95      0.82      1177
#
#     accuracy                           0.79      2365
#    macro avg       0.82      0.79      0.79      2365
# weighted avg       0.82      0.79      0.79      2365
#
#
# --------------------------------------------------
#
# Sport: Cross Country Skiing
# Training MSE: 0.1848
# Testing MSE: 0.1832
# Testing Accuracy: 0.8168
# Confusion Matrix:
#  [[ 980  396]
#  [  97 1218]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.71      0.80      1376
#            1       0.75      0.93      0.83      1315
#
#     accuracy                           0.82      2691
#    macro avg       0.83      0.82      0.82      2691
# weighted avg       0.83      0.82      0.81      2691
#
#
# --------------------------------------------------
#
# Sport: Biathlon
# Training MSE: 0.1778
# Testing MSE: 0.1875
# Testing Accuracy: 0.8125
# Confusion Matrix:
#  [[682 249]
#  [ 97 817]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.73      0.80       931
#            1       0.77      0.89      0.83       914
#
#     accuracy                           0.81      1845
#    macro avg       0.82      0.81      0.81      1845
# weighted avg       0.82      0.81      0.81      1845
#
#
# --------------------------------------------------
#
# Sport: Figure Skating
# Training MSE: 0.2276
# Testing MSE: 0.2129
# Testing Accuracy: 0.7871
# Confusion Matrix:
#  [[178  71]
#  [ 35 214]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.71      0.77       249
#            1       0.75      0.86      0.80       249
#
#     accuracy                           0.79       498
#    macro avg       0.79      0.79      0.79       498
# weighted avg       0.79      0.79      0.79       498
#
#
# --------------------------------------------------
#
# Sport: Luge
# Training MSE: 0.1460
# Testing MSE: 0.1600
# Testing Accuracy: 0.8400
# Confusion Matrix:
#  [[173  64]
#  [ 12 226]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82       237
#            1       0.78      0.95      0.86       238
#
#     accuracy                           0.84       475
#    macro avg       0.86      0.84      0.84       475
# weighted avg       0.86      0.84      0.84       475
#
#
# --------------------------------------------------
#
# Sport: Nordic Combined
# Training MSE: 0.2043
# Testing MSE: 0.1938
# Testing Accuracy: 0.8062
# Confusion Matrix:
#  [[133  59]
#  [ 16 179]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.69      0.78       192
#            1       0.75      0.92      0.83       195
#
#     accuracy                           0.81       387
#    macro avg       0.82      0.81      0.80       387
# weighted avg       0.82      0.81      0.80       387
#
#
# --------------------------------------------------
#
# Sport: Ski Jumping
# Training MSE: 0.1806
# Testing MSE: 0.1968
# Testing Accuracy: 0.8032
# Confusion Matrix:
#  [[248 116]
#  [ 20 307]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.68      0.78       364
#            1       0.73      0.94      0.82       327
#
#     accuracy                           0.80       691
#    macro avg       0.83      0.81      0.80       691
# weighted avg       0.83      0.80      0.80       691
#
#
# --------------------------------------------------
#
# Sport: Ice Hockey
# Training MSE: 0.1891
# Testing MSE: 0.1860
# Testing Accuracy: 0.8140
# Confusion Matrix:
#  [[410 188]
#  [ 38 579]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.69      0.78       598
#            1       0.75      0.94      0.84       617
#
#     accuracy                           0.81      1215
#    macro avg       0.84      0.81      0.81      1215
# weighted avg       0.83      0.81      0.81      1215
#
#
# --------------------------------------------------
#
# Sport: Bobsleigh
# Training MSE: 0.1844
# Testing MSE: 0.1945
# Testing Accuracy: 0.8055
# Confusion Matrix:
#  [[277 105]
#  [ 43 336]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.73      0.79       382
#            1       0.76      0.89      0.82       379
#
#     accuracy                           0.81       761
#    macro avg       0.81      0.81      0.80       761
# weighted avg       0.81      0.81      0.80       761
#
#
# --------------------------------------------------
#
# Sport: Baseball
# Training MSE: 0.1286
# Testing MSE: 0.1964
# Testing Accuracy: 0.8036
# Confusion Matrix:
#  [[ 70  34]
#  [ 10 110]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76       104
#            1       0.76      0.92      0.83       120
#
#     accuracy                           0.80       224
#    macro avg       0.82      0.79      0.80       224
# weighted avg       0.82      0.80      0.80       224
#
#
# --------------------------------------------------
#
# Sport: Tennis
# Training MSE: 0.1354
# Testing MSE: 0.1747
# Testing Accuracy: 0.8253
# Confusion Matrix:
#  [[279 102]
#  [ 28 335]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81       381
#            1       0.77      0.92      0.84       363
#
#     accuracy                           0.83       744
#    macro avg       0.84      0.83      0.82       744
# weighted avg       0.84      0.83      0.82       744
#
#
# --------------------------------------------------
#
# Sport: Artistic Swimming
# Training MSE: 0.1373
# Testing MSE: 0.1483
# Testing Accuracy: 0.8517
# Confusion Matrix:
#  [[ 95  38]
#  [  1 129]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.71      0.83       133
#            1       0.77      0.99      0.87       130
#
#     accuracy                           0.85       263
#    macro avg       0.88      0.85      0.85       263
# weighted avg       0.88      0.85      0.85       263
#
#
# --------------------------------------------------
#
# Sport: Rhythmic Gymnastics
# Training MSE: 0.1697
# Testing MSE: 0.2585
# Testing Accuracy: 0.7415
# Confusion Matrix:
#  [[72 31]
#  [22 80]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.70      0.73       103
#            1       0.72      0.78      0.75       102
#
#     accuracy                           0.74       205
#    macro avg       0.74      0.74      0.74       205
# weighted avg       0.74      0.74      0.74       205
#
#
# --------------------------------------------------
#
# Sport: Table Tennis
# Training MSE: 0.0914
# Testing MSE: 0.0943
# Testing Accuracy: 0.9057
# Confusion Matrix:
#  [[307  53]
#  [ 10 298]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91       360
#            1       0.85      0.97      0.90       308
#
#     accuracy                           0.91       668
#    macro avg       0.91      0.91      0.91       668
# weighted avg       0.91      0.91      0.91       668
#
#
# --------------------------------------------------
#
# Sport: Badminton
# Training MSE: 0.1512
# Testing MSE: 0.1592
# Testing Accuracy: 0.8408
# Confusion Matrix:
#  [[194  58]
#  [ 20 218]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83       252
#            1       0.79      0.92      0.85       238
#
#     accuracy                           0.84       490
#    macro avg       0.85      0.84      0.84       490
# weighted avg       0.85      0.84      0.84       490
#
#
# --------------------------------------------------
#
# Sport: Taekwondo
# Training MSE: 0.1093
# Testing MSE: 0.1848
# Testing Accuracy: 0.8152
# Confusion Matrix:
#  [[73 17]
#  [17 77]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81        90
#            1       0.82      0.82      0.82        94
#
#     accuracy                           0.82       184
#    macro avg       0.82      0.82      0.82       184
# weighted avg       0.82      0.82      0.82       184
#
#
# --------------------------------------------------
#
# Sport: Curling
# Training MSE: 0.2135
# Testing MSE: 0.2258
# Testing Accuracy: 0.7742
# Confusion Matrix:
#  [[66 25]
#  [17 78]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.73      0.76        91
#            1       0.76      0.82      0.79        95
#
#     accuracy                           0.77       186
#    macro avg       0.78      0.77      0.77       186
# weighted avg       0.78      0.77      0.77       186
#
#
# --------------------------------------------------
#
# Sport: Short Track Speed Skating
# Training MSE: 0.2240
# Testing MSE: 0.2368
# Testing Accuracy: 0.7632
# Confusion Matrix:
#  [[247 137]
#  [ 29 288]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.64      0.75       384
#            1       0.68      0.91      0.78       317
#
#     accuracy                           0.76       701
#    macro avg       0.79      0.78      0.76       701
# weighted avg       0.80      0.76      0.76       701
#
#
# --------------------------------------------------
#
# Sport: Freestyle Skiing
# Training MSE: 0.2265
# Testing MSE: 0.2651
# Testing Accuracy: 0.7349
# Confusion Matrix:
#  [[167  78]
#  [ 45 174]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.68      0.73       245
#            1       0.69      0.79      0.74       219
#
#     accuracy                           0.73       464
#    macro avg       0.74      0.74      0.73       464
# weighted avg       0.74      0.73      0.73       464
#
#
# --------------------------------------------------
#
# Sport: Cycling Mountain Bike
# Training MSE: 0.0972
# Testing MSE: 0.0867
# Testing Accuracy: 0.9133
# Confusion Matrix:
#  [[80  7]
#  [ 8 78]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91        87
#            1       0.92      0.91      0.91        86
#
#     accuracy                           0.91       173
#    macro avg       0.91      0.91      0.91       173
# weighted avg       0.91      0.91      0.91       173
#
#
# --------------------------------------------------
#
# Sport: Softball
# Training MSE: 0.0748
# Testing MSE: 0.1019
# Testing Accuracy: 0.8981
# Confusion Matrix:
#  [[50  2]
#  [ 9 47]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.96      0.90        52
#            1       0.96      0.84      0.90        56
#
#     accuracy                           0.90       108
#    macro avg       0.90      0.90      0.90       108
# weighted avg       0.91      0.90      0.90       108
#
#
# --------------------------------------------------
#
# Sport: Beach Volleyball
# Training MSE: 0.1384
# Testing MSE: 0.1608
# Testing Accuracy: 0.8392
# Confusion Matrix:
#  [[79 21]
#  [11 88]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.79      0.83       100
#            1       0.81      0.89      0.85        99
#
#     accuracy                           0.84       199
#    macro avg       0.84      0.84      0.84       199
# weighted avg       0.84      0.84      0.84       199
#
#
# --------------------------------------------------
#
# Sport: Snowboarding
# Training MSE: 0.2188
# Testing MSE: 0.2034
# Testing Accuracy: 0.7966
# Confusion Matrix:
#  [[166  59]
#  [ 36 206]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       225
#            1       0.78      0.85      0.81       242
#
#     accuracy                           0.80       467
#    macro avg       0.80      0.79      0.80       467
# weighted avg       0.80      0.80      0.80       467
#
#
# --------------------------------------------------
#
# Sport: Trampolining
# Training MSE: 0.0550
# Testing MSE: 0.1000
# Testing Accuracy: 0.9000
# Confusion Matrix:
#  [[21  3]
#  [ 2 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89        24
#            1       0.89      0.92      0.91        26
#
#     accuracy                           0.90        50
#    macro avg       0.90      0.90      0.90        50
# weighted avg       0.90      0.90      0.90        50
#
#
# --------------------------------------------------
#
# Sport: Triathlon
# Training MSE: 0.0960
# Testing MSE: 0.1179
# Testing Accuracy: 0.8821
# Confusion Matrix:
#  [[101  15]
#  [ 10  86]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       116
#            1       0.85      0.90      0.87        96
#
#     accuracy                           0.88       212
#    macro avg       0.88      0.88      0.88       212
# weighted avg       0.88      0.88      0.88       212
#
#
# --------------------------------------------------
#
# Sport: Cycling BMX Racing
# Training MSE: 0.0829
# Testing MSE: 0.1273
# Testing Accuracy: 0.8727
# Confusion Matrix:
#  [[23  6]
#  [ 1 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87        29
#            1       0.81      0.96      0.88        26
#
#     accuracy                           0.87        55
#    macro avg       0.88      0.88      0.87        55
# weighted avg       0.89      0.87      0.87        55
#
#
# --------------------------------------------------
#
# Sport: Marathon Swimming
# Training MSE: 0.0482
# Testing MSE: 0.1207
# Testing Accuracy: 0.8793
# Confusion Matrix:
#  [[22  3]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        25
#            1       0.91      0.88      0.89        33
#
#     accuracy                           0.88        58
#    macro avg       0.88      0.88      0.88        58
# weighted avg       0.88      0.88      0.88        58
#
#
# --------------------------------------------------
#
# Sport: Skeleton
# Training MSE: 0.0925
# Testing MSE: 0.1579
# Testing Accuracy: 0.8421
# Confusion Matrix:
#  [[18  5]
#  [ 4 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80        23
#            1       0.86      0.88      0.87        34
#
#     accuracy                           0.84        57
#    macro avg       0.84      0.83      0.83        57
# weighted avg       0.84      0.84      0.84        57
#
#
# --------------------------------------------------
#
# Sport: Golf
# Training MSE: 0.0140
# Testing MSE: 0.0556
# Testing Accuracy: 0.9444
# Confusion Matrix:
#  [[28  2]
#  [ 1 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        30
#            1       0.92      0.96      0.94        24
#
#     accuracy                           0.94        54
#    macro avg       0.94      0.95      0.94        54
# weighted avg       0.95      0.94      0.94        54
#
#
# --------------------------------------------------
#
# Sport: Rugby Sevens
# Training MSE: 0.0986
# Testing MSE: 0.1024
# Testing Accuracy: 0.8976
# Confusion Matrix:
#  [[61 11]
#  [ 2 53]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90        72
#            1       0.83      0.96      0.89        55
#
#     accuracy                           0.90       127
#    macro avg       0.90      0.91      0.90       127
# weighted avg       0.91      0.90      0.90       127
#
#
# --------------------------------------------------
#
# Sport: 3x3 Basketball
# Training MSE: 0.0000
# Testing MSE: 1.0000
# Testing Accuracy: 0.0000
# Confusion Matrix:
#  [[0 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00       1.0
#            1       0.00      1.00      0.00       0.0
#
#     accuracy                           0.00       1.0
#    macro avg       0.50      0.50      0.00       1.0
# weighted avg       1.00      0.00      0.00       1.0
#
#
# --------------------------------------------------
#
# Sport: Skateboarding
# Training MSE: 0.2353
# Testing MSE: 0.0000
# Testing Accuracy: 1.0000
# Confusion Matrix:
#  [[3 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5
#
#
# --------------------------------------------------
#
# Sport: Surfing
# Training MSE: 0.0000
# Testing MSE: 0.3333
# Testing Accuracy: 0.6667
# Confusion Matrix:
#  [[0 0]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      1.00      0.00         0
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# --------------------------------------------------

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, mean_squared_error, mean_absolute_error,
    precision_score, recall_score, confusion_matrix
)
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# Prepare a dictionary to store metrics for each model
metrics_dict = {
    "Model": [],
    "Accuracy": [],
    "Precision": [],
    "Recall": [],
    "RMSE": [],
    "MSE": [],
    "MAE": []
}

# Define models to be evaluated
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "SVM": SVC()
}

# Loop through each model, train it, and store metrics
for model_name, model in models.items():
    # Initialize lists to accumulate metrics per sport
    accuracy_list, precision_list, recall_list, rmse_list, mse_list, mae_list = [], [], [], [], [], []

    # Group the data by sport
    for sport in df_scaled['Sport'].unique():
        df_sport = df_scaled[df_scaled['Sport'] == sport]

        if df_sport.shape[0] > 0:  # Check if the sport group has enough data
            # Select features and target variable
            X = df_sport[['Scaled_BMI', 'Scaled_Age', 'Country']]
            X = pd.get_dummies(X, columns=['Country'], prefix=['Country'])
            y = df_sport['Medal_Indicator']

            # Ensure there are at least two classes
            if len(np.unique(y)) > 1:
                minority_class_size = np.min(np.bincount(y))
                k_neighbors = min(5, minority_class_size - 1) if minority_class_size > 1 else 1
                smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
                X_resampled, y_resampled = smote.fit_resample(X, y)

                # Split into training and testing sets
                X_train, X_test, y_train, y_test = train_test_split(
                    X_resampled, y_resampled, test_size=0.2, random_state=42
                )

                # Train the model
                model.fit(X_train, y_train)

                # Make predictions
                y_pred = model.predict(X_test)

                # Calculate metrics
                accuracy = accuracy_score(y_test, y_pred)
                precision = precision_score(y_test, y_pred, zero_division=1)
                recall = recall_score(y_test, y_pred, zero_division=1)
                mse = mean_squared_error(y_test, y_pred)
                mae = mean_absolute_error(y_test, y_pred)
                rmse = np.sqrt(mse)

                # Append metrics to lists
                accuracy_list.append(accuracy)
                precision_list.append(precision)
                recall_list.append(recall)
                mse_list.append(mse)
                mae_list.append(mae)
                rmse_list.append(rmse)

    # Store average metrics for the current model
    metrics_dict["Model"].append(model_name)
    metrics_dict["Accuracy"].append(np.mean(accuracy_list))
    metrics_dict["Precision"].append(np.mean(precision_list))
    metrics_dict["Recall"].append(np.mean(recall_list))
    metrics_dict["MSE"].append(np.mean(mse_list))
    metrics_dict["MAE"].append(np.mean(mae_list))
    metrics_dict["RMSE"].append(np.mean(rmse_list))

# Convert the dictionary to a DataFrame for easier visualization
metrics_df = pd.DataFrame(metrics_dict)
print(metrics_df)

# Plot the metrics for visualization
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
fig.suptitle("Model Comparison Across Metrics")

# Accuracy plot
axes[0, 0].bar(metrics_df["Model"], metrics_df["Accuracy"], color=['skyblue', 'lightgreen', 'salmon'])
axes[0, 0].set_title("Accuracy")
axes[0, 0].set_ylabel("Score")

# Precision plot
axes[0, 1].bar(metrics_df["Model"], metrics_df["Precision"], color=['skyblue', 'lightgreen', 'salmon'])
axes[0, 1].set_title("Precision")
axes[0, 1].set_ylabel("Score")

# Recall plot
axes[0, 2].bar(metrics_df["Model"], metrics_df["Recall"], color=['skyblue', 'lightgreen', 'salmon'])
axes[0, 2].set_title("Recall")
axes[0, 2].set_ylabel("Score")

# MSE plot
axes[1, 0].bar(metrics_df["Model"], metrics_df["MSE"], color=['skyblue', 'lightgreen', 'salmon'])
axes[1, 0].set_title("MSE")
axes[1, 0].set_ylabel("Error")

# MAE plot
axes[1, 1].bar(metrics_df["Model"], metrics_df["MAE"], color=['skyblue', 'lightgreen', 'salmon'])
axes[1, 1].set_title("MAE")
axes[1, 1].set_ylabel("Error")

# RMSE plot
axes[1, 2].bar(metrics_df["Model"], metrics_df["RMSE"], color=['skyblue', 'lightgreen', 'salmon'])
axes[1, 2].set_title("RMSE")
axes[1, 2].set_ylabel("Error")

# Show plot
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
#                  Model  Accuracy  Precision    Recall      RMSE       MSE  \
# 0  Logistic Regression  0.763170   0.738240  0.838452  0.475497  0.236830
# 1        Random Forest  0.850069   0.844346  0.880453  0.371199  0.149931
# 2                  SVM  0.800132   0.768485  0.885185  0.432972  0.199868
#
#         MAE
# 0  0.236830
# 1  0.149931
# 2  0.199868

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import numpy as np

def predict_medal_chance(bmi, age, country, sport, df_scaled):
    df_sport = df_scaled[df_scaled['Sport'] == sport]
    if df_sport.shape[0] == 0:
        return "Not enough data for this sport."

    # Select features and target variable
    X = df_sport[['Scaled_BMI', 'Scaled_Age', 'Country']]
    X = pd.get_dummies(X, columns=['Country'], prefix=['Country'])
    y = df_sport['Medal_Indicator']

    # Ensure there are at least two classes
    if len(np.unique(y)) > 1:
        minority_class_size = np.min(np.bincount(y))
        k_neighbors = min(5, minority_class_size - 1) if minority_class_size > 1 else 1
        smote = SMOTE(random_state=42, k_neighbors=k_neighbors)
        X_resampled, y_resampled = smote.fit_resample(X, y)

        # Split into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(
            X_resampled, y_resampled, test_size=0.2, random_state=42
        )

        # Train a Random Forest Classifier
        model = RandomForestClassifier(random_state=42)
        model.fit(X_train, y_train)

        # Create a new input DataFrame with the provided features
        new_data = pd.DataFrame({
            'Scaled_BMI': [bmi],
            'Scaled_Age': [age],
            'Country': [country]
        })

        # One-hot encode the country feature
        new_data = pd.get_dummies(new_data, columns=['Country'], prefix=['Country'])
        # Align columns with the training data
        new_data = new_data.reindex(columns=X_train.columns, fill_value=0)

        # Make a prediction
        prediction = model.predict_proba(new_data)

        # Return the probability of winning a medal (class 1)
        return prediction[0][1]

    else:
        return "Not enough data or only one class in target variable for this sport."


# Get user input for the parameters
bmi = float(input("Enter the athlete's BMI: "))
age = int(input("Enter the athlete's age: "))
country = input("Enter the athlete's country: ")
sport = input("Enter the sport: ")

probability = predict_medal_chance(bmi, age, country, sport, df_scaled)
print(f"The probability of winning a medal is: {probability}")
# Out:
# Enter the athlete's BMI: 25
# Enter the athlete's age: 22
# Enter the athlete's country: USA
# Enter the sport: Swimming
# The probability of winning a medal is: 0.98
